# %%
from langgraph.graph import StateGraph, END
from langgraph.graph.message import add_messages
import google.generativeai as genai
from langchain.schema import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import re

# %%
# Gemini Flash for faster planning
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key="AIzaSyAUH70gKFSmR52QAbZq4fJFM3WSbTYCHp8",
    temperature=0.3
)

# %%
# ==== 1. User Travel Input ====
def get_travel_input(state):
    state["travel_input"] = {
        "destination": "Hyderabad",
        "area": "HITEC City",
        "duration_days": 3,
        "budget": 7000,  # INR per person
        "travel_type": "budget",
        "interests": ["sightseeing", "local food"]
    }
    return state

# %%
# ==== 2. Analyze Preferences ====
def analyze_travel_profile(state):
    t = state["travel_input"]
    prompt = f"""
    You are a smart travel agent. Analyze the following user preferences:
    - Destination: {t['destination']} ({t['area']})
    - Duration: {t['duration_days']} days
    - Budget: ₹{t['budget']} total
    - Travel type: {t['travel_type']}
    - Interests: {", ".join(t['interests'])}

    Give a short summary and note any constraints or considerations.
    """
    state["travel_summary"] = llm.predict(prompt)
    return state

# %%
# ==== 3. Suggest Hotels ====
def suggest_hotels(state):
    t = state["travel_input"]
    prompt = f"""
    Recommend 2 budget-friendly hotels in or near {t['area']}, {t['destination']} 
    for {t['duration_days']} days stay under ₹{t['budget']} total.

    For each hotel, include:
    - Name
    - Approx. price per night
    - Total cost
    - Reason it's a good choice
    """
    state["hotel_options"] = llm.predict(prompt)
    return state

# %%
# ==== 4. Places to Visit ====
def suggest_places(state):
    t = state["travel_input"]
    prompt = f"""
    Suggest 5 must-visit places in or near {t['destination']} focusing on:
    - Interests: {", ".join(t['interests'])}
    - Budget constraints (travel type: {t['travel_type']})
    - Located within 10-15 km of {t['area']}

    Include place name and reason to visit.
    """
    state["places_to_visit"] = llm.predict(prompt)
    return state

# %%
# ==== 5. Cost Estimation ====
def cost_estimator(state):
    prompt = f"""
    Estimate the total travel cost for this 3-day trip to Hyderabad with the following:
    - Hotel: use details below
{state['hotel_options']}

    - Sightseeing: based on these places
{state['places_to_visit']}

    Break down cost for:
    - Hotel stay
    - Transport/local travel
    - Food
    - Entry tickets (if any)
    - Misc

    Give total cost and whether it's within ₹{state['travel_input']['budget']}.
    """
    state["cost_estimate"] = llm.predict(prompt)
    return state

# %%
# ==== 6. Final Travel Plan ====
def travel_summary(state):
    summary = f"""
    Travel Summary:
{state['travel_summary']}

    Hotel Options:
{state['hotel_options']}

    Places to Visit:
{state['places_to_visit']}

    Cost Estimate:
{state['cost_estimate']}
"""
    state["summary"] = summary
    return state

# %%
# ==== BUILD GRAPH ====
graph = StateGraph(dict)
graph.add_node("input", get_travel_input)
graph.add_node("analyze", analyze_travel_profile)
graph.add_node("hotels", suggest_hotels)
graph.add_node("places", suggest_places)
graph.add_node("cost", cost_estimator)
graph.add_node("summary", travel_summary)

graph.set_entry_point("input")
graph.add_edge("input", "analyze")
graph.add_edge("analyze", "hotels")
graph.add_edge("hotels", "places")
graph.add_edge("places", "cost")
graph.add_edge("cost", "summary")
graph.set_finish_point("summary")

# %%
graph.compile()

# %%
result = graph.compile().invoke({})
print(result["summary"])
# Out:
# C:\Users\omkar\AppData\Local\Temp\ipykernel_11340\4203023958.py:14: LangChainDeprecationWarning: The method `BaseChatModel.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   state["travel_summary"] = llm.predict(prompt)
#     Travel Summary:
# Okay, here's a summary and analysis of the user's travel preferences:
#
# **Summary:**
#
# The user wants a budget-friendly 3-day trip to Hyderabad (specifically HITEC City) focusing on sightseeing and experiencing local cuisine, with a total budget of ₹7000.
#
# **Constraints and Considerations:**
#
# *   **Tight Budget:** ₹7000 for 3 days in a major city requires careful planning and prioritization. Accommodation, transportation, and food will need to be economical.
# *   **Location Specificity:** HITEC City is a tech hub, so sightseeing options within walking distance might be limited. Transportation to historical and cultural sites will be necessary.
# *   **Time Constraint:** 3 days is relatively short, so efficient itinerary planning is crucial to maximize sightseeing and food experiences.
# *   **Balancing Interests:** Sightseeing and local food are broad interests. We need to identify specific attractions and food experiences that fit the budget and time frame.
# *   **Travel Style:** "Budget" travel implies a willingness to compromise on luxury and prioritize affordability. This might mean choosing budget-friendly accommodation, public transport, and street food over upscale options.
#
# **Next Steps:**
#
# To create a suitable itinerary, I need to research:
#
# *   **Budget-friendly accommodation options** near HITEC City or with good connectivity.
# *   **Affordable transportation options** (local buses, metro, ride-sharing).
# *   **Free or low-cost sightseeing attractions** in and around Hyderabad.
# *   **Local food experiences** that are both authentic and budget-friendly.
# *   **Opening hours and travel times** between attractions to optimize the itinerary.
#
#     Hotel Options:
# Okay, here are two budget-friendly hotel options in or near HITEC City, Hyderabad, that should fall within your ₹7000 budget for a 3-day stay:
#
# **Hotel 1: Hotel NK Grand Park**
#
# *   **Name:** Hotel NK Grand Park
# *   **Approx. Price Per Night:** ₹2000 - ₹2300 (Prices can fluctuate based on availability and booking platform)
# *   **Total Cost (3 Nights):** ₹6000 - ₹6900
# *   **Reason it's a good choice:**
#     *   **Location:** Relatively close to HITEC City, making it convenient for business or leisure activities in the area.
#     *   **Value for Money:** Offers decent amenities for the price, including comfortable rooms, Wi-Fi, and often breakfast.
#     *   **Reviews:** Generally receives positive reviews for cleanliness and helpful staff.
#     *   **Accessibility:** Easy access to public transportation and ride-sharing services.
#
# **Hotel 2: Hotel Sitara Grand - Hitech City**
#
# *   **Name:** Hotel Sitara Grand - Hitech City
# *   **Approx. Price Per Night:** ₹1800 - ₹2200 (Prices can fluctuate based on availability and booking platform)
# *   **Total Cost (3 Nights):** ₹5400 - ₹6600
# *   **Reason it's a good choice:**
#     *   **Location:** Located in the heart of HITEC City, making it ideal for those working or visiting the area.
#     *   **Amenities:** Offers essential amenities like Wi-Fi, room service, and comfortable beds.
#     *   **Budget-Friendly:** Consistently offers competitive rates, making it a great option for budget-conscious travelers.
#     *   **Accessibility:** Close to major IT companies, shopping malls, and restaurants.
#
# **Important Notes:**
#
# *   **Price Fluctuations:** Hotel prices can vary significantly depending on the time of year, day of the week, and availability.  It's crucial to check prices on multiple booking platforms (e.g., MakeMyTrip, Booking.com, Goibibo, Agoda, etc.) to find the best deal.
# *   **Book in Advance:** To secure the best rates, book your hotel well in advance, especially if you're traveling during peak season.
# *   **Read Reviews:** Before booking, read recent reviews from other travelers to get an idea of the hotel's current condition and service quality.
# *   **Check Inclusions:** Confirm what's included in the room rate (e.g., breakfast, Wi-Fi, taxes) to avoid any surprises.
# *   **Negotiate:** Don't hesitate to contact the hotel directly and ask if they can offer a better rate, especially for a longer stay.
#
# I hope this helps you find a great and affordable hotel for your trip to HITEC City!
#
#     Places to Visit:
# Okay, here are 5 must-visit places in or near Hyderabad, focusing on sightseeing, local food, budget travel, and located within 10-15 km of HITEC City:
#
# **1.  Shilparamam (Hitech City):**
#
# *   **Reason to Visit:** This is a crafts village showcasing the rich art, culture, and traditions of India, particularly Andhra Pradesh and Telangana. You can witness artisans at work, buy handicrafts, enjoy cultural performances, and sample local snacks. It's a great place to experience the local culture without traveling far.
# *   **Budget-Friendly:** Entry fee is minimal (around INR 100-150). Food stalls offer affordable local snacks and meals.
# *   **Distance from HITEC City:** Within HITEC City itself.
#
# **2.  Durgam Cheruvu (Secret Lake):**
#
# *   **Reason to Visit:** A scenic lake surrounded by rocky terrain. You can enjoy boat rides, take a walk along the promenade, or simply relax and enjoy the views. The newly built cable bridge adds to the charm. There are also food stalls and restaurants around the lake.
# *   **Budget-Friendly:** Boat rides are reasonably priced. You can pack your own snacks and drinks to save money.
# *   **Distance from HITEC City:** Approximately 5-7 km.
#
# **3.  Inorbit Mall Cyberabad:**
#
# *   **Reason to Visit:** Experience the local food scene at the food court, which offers a variety of Hyderabadi and Indian cuisines at affordable prices. Also, you can enjoy window shopping and people-watching.
# *   **Budget-Friendly:** Food court options cater to various budgets.
# *   **Distance from HITEC City:** Within HITEC City itself.
#
# **4.  Gachibowli Miyapur Metro Line:**
#
# *   **Reason to Visit:** Take a ride on the Hyderabad Metro. It's a modern and efficient way to see the city and get a glimpse of different neighborhoods. You can get off at various stations and explore the surrounding areas.
# *   **Budget-Friendly:** Metro fares are very affordable.
# *   **Distance from HITEC City:** HITEC City has a metro station.
#
# **5.  Street Food at Madhapur:**
#
# *   **Reason to Visit:** Madhapur is known for its vibrant street food scene, especially in the evenings. You can find a wide variety of local delicacies like *pani puri, chaat, dosas, idlis, and kebabs* at very affordable prices. It's a great way to experience the local flavors.
# *   **Budget-Friendly:** Street food is generally very cheap.
# *   **Distance from HITEC City:** Within Madhapur, which is adjacent to HITEC City.
#
# **Important Considerations for Budget Travel:**
#
# *   **Transportation:** Use public transport (metro, buses) or auto-rickshaws to save money on transportation. Negotiate the fares with auto drivers beforehand.
# *   **Accommodation:** If you need accommodation, consider budget-friendly hotels or guesthouses in the HITEC City or Gachibowli area.
# *   **Food:** Opt for street food or local restaurants instead of expensive tourist traps.
# *   **Bargaining:** Don't hesitate to bargain when shopping for souvenirs or handicrafts.
#
# Enjoy your trip to Hyderabad!
#
#     Cost Estimate:
# Okay, let's break down the estimated costs for your 3-day trip to Hyderabad, based on the information provided and aiming for a budget-friendly experience.  I'll use the lower end of the hotel price range to be conservative.
#
# **1. Hotel Stay (3 Nights):**
#
# *   **Hotel:** Hotel Sitara Grand - Hitech City (Lower end of estimate)
# *   **Cost:** ₹5400 (₹1800/night x 3 nights)
#
# **2. Transport/Local Travel:**
#
# *   **Metro Rides:** Assuming 4 metro rides (airport to hotel, sightseeing, etc.) at an average of ₹30 per ride.  ₹30 x 4 = ₹120
# *   **Auto-rickshaws/Ride-Sharing:**  Allowing for a few short auto/ride-sharing trips (e.g., to street food, Durgam Cheruvu) - estimate ₹300 total.
# *   **Total Transport:** ₹120 + ₹300 = ₹420
#
# **3. Food:**
#
# *   **Breakfast:** Assuming breakfast is included in the hotel stay (check when booking). If not, budget ₹100/day for a simple breakfast = ₹300
# *   **Lunch:**  Focusing on affordable options like street food or local restaurants.  ₹200/day x 3 days = ₹600
# *   **Dinner:** Similar to lunch, aiming for budget-friendly choices. ₹250/day x 3 days = ₹750
# *   **Snacks/Drinks:**  Allowing for some snacks and drinks throughout the day. ₹150/day x 3 days = ₹450
# *   **Total Food:** ₹300 + ₹600 + ₹750 + ₹450 = ₹2100
#
# **4. Entry Tickets:**
#
# *   **Shilparamam:** ₹150
# *   **Durgam Cheruvu Boat Ride (Optional):** ₹200 (This is optional, you can skip it)
# *   **Total Entry Tickets:** ₹150 + ₹200 = ₹350
#
# **5. Miscellaneous:**
#
# *   **Souvenirs:**  Allowing a small budget for souvenirs. ₹300
# *   **Unexpected Expenses:**  It's always good to have a small buffer for unexpected costs. ₹200
# *   **Total Miscellaneous:** ₹300 + ₹200 = ₹500
#
# **Total Estimated Cost:**
#
# *   Hotel: ₹5400
# *   Transport: ₹420
# *   Food: ₹2100
# *   Entry Tickets: ₹350
# *   Miscellaneous: ₹500
# *   **Grand Total: ₹8770**
#
# **Is it within ₹7000?**
#
# No, the estimated total cost is ₹8770, which is over your ₹7000 budget.
#
# **How to Bring it Within Budget:**
#
# Here's how you can potentially bring the trip within your ₹7000 budget:
#
# *   **Hotel:** Look for even cheaper hotels or consider guesthouses.  Even saving ₹400 on the hotel would help.
# *   **Food:** Be even more frugal with food. Stick to street food and pack some snacks. Reduce the daily food budget by ₹300.
# *   **Entry Tickets:** Skip the Durgam Cheruvu boat ride (saving ₹200).
# *   **Transportation:** Walk more and rely on public transport as much as possible. Reduce the auto/ride-sharing budget by ₹100.
# *   **Souvenirs:** Reduce the souvenir budget or skip it entirely.
#
# By making these adjustments, you could potentially bring the total cost down to around ₹7000 or slightly below.  It will require being mindful of your spending and prioritizing budget-friendly options.

# %%
# ==== BUILD GRAPH ====
graph = StateGraph(dict)
graph.add_node("input", get_travel_input)
graph.add_node("analyze", analyze_travel_profile)
graph.add_node("hotels", suggest_hotels)
graph.add_node("places", suggest_places)
graph.add_node("cost", cost_estimator)
graph.add_node("summary", travel_summary)

graph.set_entry_point("input")
graph.add_edge("input", "analyze")
graph.add_edge("analyze", "hotels")
graph.add_edge("hotels", "places")
graph.add_edge("places", "cost")
graph.add_edge("cost", "summary")
graph.set_finish_point("summary")

# ==== RUN ====
result = graph.compile().invoke({})
print(result["summary"])
