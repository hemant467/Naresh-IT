# %%
# pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt") # .pt - PyTorch Model

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read() # read the video boolean value & image
    results = model(img, stream=True) # passing image to models

    # coordinates
    for r in results: # results
        boxes = r.boxes # boxes method

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3) # image value ; top ; bottom ; (R,G,B) ; value

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 482.2KB/s 13.3ss<0.0s4s1.5s
#
# 0: 480x640 (no detections), 248.0ms
# Speed: 6.2ms preprocess, 248.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 252.1ms
# Speed: 20.1ms preprocess, 252.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.0ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 6.7ms preprocess, 222.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 5.2ms preprocess, 220.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 6.9ms preprocess, 234.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 6.9ms preprocess, 235.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 8.1ms preprocess, 226.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 8.0ms preprocess, 213.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 11.3ms preprocess, 210.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 237.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 6.7ms preprocess, 237.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.8ms preprocess, 209.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.8ms preprocess, 212.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 219.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 8.3ms preprocess, 219.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.3ms preprocess, 206.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 220.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 3.3ms preprocess, 220.0ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.6ms preprocess, 250.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 236.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.26
# Class name --> person
# Speed: 7.5ms preprocess, 236.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 206.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 280.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.5ms preprocess, 280.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 201.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.1ms preprocess, 201.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 219.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.5ms preprocess, 216.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.2ms preprocess, 212.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 203.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.4ms preprocess, 211.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 6.0ms preprocess, 235.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 244.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.1ms preprocess, 244.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 212.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.1ms preprocess, 218.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 196.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.7ms preprocess, 224.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.1ms preprocess, 232.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.8ms preprocess, 215.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.4ms preprocess, 193.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.7ms preprocess, 205.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.1ms preprocess, 227.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 227.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.9ms preprocess, 238.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.8ms preprocess, 226.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.0ms preprocess, 212.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.3ms preprocess, 207.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.7ms preprocess, 205.5ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.6ms preprocess, 216.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.0ms preprocess, 222.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.1ms preprocess, 204.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.8ms preprocess, 251.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.5ms preprocess, 196.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 238.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 223.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Speed: 3.6ms preprocess, 223.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 273.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.3ms preprocess, 273.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.4ms preprocess, 208.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.9ms preprocess, 199.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.4ms preprocess, 198.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 6.3ms preprocess, 209.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.3ms preprocess, 211.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 206.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.0ms preprocess, 192.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.7ms preprocess, 194.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 6.1ms preprocess, 197.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.4ms preprocess, 211.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 6.3ms preprocess, 183.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.7ms preprocess, 210.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.1ms preprocess, 210.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.2ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.1ms preprocess, 192.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.9ms preprocess, 206.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.4ms preprocess, 214.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 203.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.1ms preprocess, 211.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.1ms preprocess, 200.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 305.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.3ms preprocess, 305.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 215.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.0ms preprocess, 205.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 202.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 3.1ms preprocess, 202.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 206.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 3.3ms preprocess, 206.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 213.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 5.2ms preprocess, 213.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 189.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.2ms preprocess, 189.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 5.6ms preprocess, 171.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 208.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 4.0ms preprocess, 208.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 200.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 4.6ms preprocess, 200.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 274.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.0ms preprocess, 274.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 7.8ms preprocess, 235.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 3.9ms preprocess, 205.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 3.4ms preprocess, 205.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 260.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 4.4ms preprocess, 260.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 4.3ms preprocess, 240.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 327.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 5.1ms preprocess, 327.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 200.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 6.6ms preprocess, 200.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 6.1ms preprocess, 205.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.4ms preprocess, 229.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 204.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 2.9ms preprocess, 204.5ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 295.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 10.1ms preprocess, 295.6ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 232.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 7.3ms preprocess, 232.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 3.9ms preprocess, 217.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 239.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 2.9ms preprocess, 239.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 209.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.4ms preprocess, 209.1ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 197.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.7ms preprocess, 197.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 201.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 7.0ms preprocess, 201.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 5.6ms preprocess, 217.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 321.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 4.3ms preprocess, 321.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 256.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 6.8ms preprocess, 256.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 251.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 5.5ms preprocess, 251.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 230.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 4.6ms preprocess, 230.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 274.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 5.0ms preprocess, 274.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.7ms preprocess, 223.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.6ms preprocess, 228.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.8ms preprocess, 220.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.9ms preprocess, 198.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.2ms preprocess, 196.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.5ms preprocess, 195.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.9ms preprocess, 199.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.1ms preprocess, 320.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.7ms preprocess, 169.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 6.2ms preprocess, 218.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 5.4ms preprocess, 208.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.4ms preprocess, 193.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 6.5ms preprocess, 221.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.2ms preprocess, 250.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.3ms preprocess, 224.1ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.6ms preprocess, 224.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 5.6ms preprocess, 222.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 270.3ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 4.4ms preprocess, 270.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.4ms
# Confidence ---> 0.42
# Class name --> person
# Speed: 9.0ms preprocess, 232.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.9ms
# Confidence ---> 0.48
# Class name --> person
# Speed: 3.1ms preprocess, 208.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 211.4ms
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 5.6ms preprocess, 211.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.8ms
# Confidence ---> 0.5
# Class name --> person
# Speed: 4.9ms preprocess, 214.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 4.3ms preprocess, 209.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 207.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 3.8ms preprocess, 207.5ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 268.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 268.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.2ms preprocess, 225.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.7ms preprocess, 226.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 233.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.1ms preprocess, 233.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.5ms preprocess, 322.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.9ms preprocess, 194.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 228.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Speed: 4.1ms preprocess, 228.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 314.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 6.2ms preprocess, 220.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.4ms preprocess, 207.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.4ms preprocess, 227.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 212.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 251.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 366.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.0ms preprocess, 366.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.2ms preprocess, 220.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.9ms preprocess, 228.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.5ms preprocess, 204.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.2ms preprocess, 310.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.5ms preprocess, 222.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.9ms preprocess, 209.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 181.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 222.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.9ms preprocess, 250.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 271.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.0ms preprocess, 271.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 249.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.6ms preprocess, 249.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 242.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 242.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 323.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 7.0ms preprocess, 323.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.4ms preprocess, 172.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.9ms preprocess, 151.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 191.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.5ms preprocess, 166.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.3ms preprocess, 190.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.0ms preprocess, 131.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.1ms preprocess, 194.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.1ms preprocess, 210.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 4.0ms preprocess, 199.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 146.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.2ms preprocess, 146.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.8ms preprocess, 142.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.3ms preprocess, 159.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 149.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 8.7ms preprocess, 149.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.1ms preprocess, 158.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 161.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 304.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.0ms preprocess, 304.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.8ms preprocess, 179.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.8ms preprocess, 186.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 7.5ms preprocess, 184.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 173.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.4ms preprocess, 193.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 13.9ms preprocess, 155.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 336.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 9.6ms preprocess, 336.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 419.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.9ms preprocess, 419.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.8ms preprocess, 225.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.7ms preprocess, 235.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.6ms preprocess, 208.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 233.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.1ms preprocess, 233.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.3ms preprocess, 229.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 243.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 3.1ms preprocess, 243.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.2ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 4.3ms preprocess, 231.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 266.0ms
# Confidence ---> 0.66
# Class name --> person
# Speed: 3.2ms preprocess, 266.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.9ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.8ms preprocess, 179.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.0ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.2ms preprocess, 183.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.8ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.9ms preprocess, 173.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.7ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 3.6ms preprocess, 179.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.1ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.9ms preprocess, 177.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.5ms preprocess, 190.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.9ms preprocess, 169.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 240.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.0ms preprocess, 240.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.6ms preprocess, 210.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 242.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.3ms preprocess, 242.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.4ms preprocess, 197.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.4ms preprocess, 170.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 178.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 3.8ms preprocess, 178.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 170.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 3.5ms preprocess, 170.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 258.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.2ms preprocess, 258.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 183.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 4.0ms preprocess, 183.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 3.8ms preprocess, 175.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.4ms preprocess, 196.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.3ms preprocess, 180.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 181.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 3.5ms preprocess, 181.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 182.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.7ms preprocess, 241.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.3ms preprocess, 181.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.3ms preprocess, 184.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.8ms preprocess, 180.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.9ms preprocess, 180.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 183.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.6ms preprocess, 175.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.6ms preprocess, 251.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.8ms preprocess, 178.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.8ms preprocess, 186.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.3ms preprocess, 190.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 177.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.2ms preprocess, 278.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.7ms
# Confidence ---> 0.49
# Class name --> person
# Speed: 3.0ms preprocess, 183.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 252.7ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.2ms preprocess, 252.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.1ms
# Confidence ---> 0.32
# Class name --> person
# Speed: 3.0ms preprocess, 174.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.6ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 3.5ms preprocess, 171.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.5ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 3.9ms preprocess, 179.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 181.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.0ms preprocess, 181.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 4.5ms preprocess, 175.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 170.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 2.8ms preprocess, 170.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 227.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.6ms preprocess, 227.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 210.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.5ms preprocess, 210.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 205.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 3.9ms preprocess, 205.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 180.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 7.1ms preprocess, 180.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 183.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.9ms preprocess, 183.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.9ms preprocess, 175.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 237.8ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.6ms preprocess, 237.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 4.0ms preprocess, 177.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 173.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 3.0ms preprocess, 173.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 170.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 4.1ms preprocess, 170.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 193.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 3.7ms preprocess, 193.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 4.1ms preprocess, 177.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 248.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 4.1ms preprocess, 248.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toothbrush, 177.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 3.4ms preprocess, 177.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toothbrush, 235.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.8ms preprocess, 235.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 188.9ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 3.4ms preprocess, 188.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 163.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 3.2ms preprocess, 163.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 172.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 3.3ms preprocess, 172.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 250.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.3ms preprocess, 250.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 168.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 3.4ms preprocess, 168.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 176.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 3.9ms preprocess, 176.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 183.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 3.1ms preprocess, 183.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 apple, 161.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.54
# Class name --> apple
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.3ms preprocess, 161.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# ...
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.6ms preprocess, 157.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 152.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 4.1ms preprocess, 152.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 179.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 3.3ms preprocess, 179.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 164.9ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.6ms preprocess, 164.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 140.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 3.1ms preprocess, 140.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 159.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 3.3ms preprocess, 159.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 142.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.0ms preprocess, 142.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 154.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 2.9ms preprocess, 154.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 136.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 3.0ms preprocess, 136.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 165.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.5ms preprocess, 165.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 154.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 3.3ms preprocess, 154.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 137.8ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.2ms preprocess, 137.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 151.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.2ms preprocess, 151.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 161.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 3.9ms preprocess, 161.3ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 144.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 3.4ms preprocess, 144.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 167.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.2ms preprocess, 167.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 176.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 4.0ms preprocess, 176.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 180.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.3ms preprocess, 180.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 bird, 185.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> bird
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.3ms preprocess, 185.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 180.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 3.3ms preprocess, 180.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 160.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.5ms preprocess, 160.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 152.1ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.7ms preprocess, 152.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 152.0ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.4ms preprocess, 152.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 149.8ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.0ms preprocess, 149.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 142.0ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.1ms preprocess, 142.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 139.8ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 3.5ms preprocess, 139.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 155.6ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 3.1ms preprocess, 155.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 144.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.9ms preprocess, 144.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 145.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 4.0ms preprocess, 145.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 165.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 3.3ms preprocess, 165.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 179.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 3.8ms preprocess, 179.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 163.9ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 3.5ms preprocess, 163.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 161.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 3.6ms preprocess, 161.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 147.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.7ms preprocess, 147.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 138.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 3.5ms preprocess, 138.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 146.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 3.9ms preprocess, 146.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 154.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 3.7ms preprocess, 154.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 142.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.3ms preprocess, 142.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 142.6ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 3.9ms preprocess, 142.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 186.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.8ms preprocess, 186.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 184.7ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 4.7ms preprocess, 184.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 162.6ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.3ms preprocess, 162.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 150.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 4.8ms preprocess, 150.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 157.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 3.8ms preprocess, 157.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 158.7ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.6ms preprocess, 158.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("path/to/video.mp4")
assert cap.isOpened(), "Error reading video file"

# region_points = [(20, 400), (1080, 400)]                                      # line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # rectangle region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon region

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize object counter object
counter = solutions.ObjectCounter(
    show=True,  # display the output
    region=region_points,  # pass region points
    model="yolo11n.pt",  # model="yolo11n-obb.pt" for object counting with OBB model.
    # classes=[0, 2],  # count specific classes i.e. person and car with COCO pretrained model.
    # tracker="botsort.yaml",  # choose trackers i.e "bytetrack.yaml"
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = counter(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Naresh IT\\AI learnings'

# %% [markdown]
# https://docs.ultralytics.com/models/

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")

# Start tracking objects in a video
# You can also use live video streams or webcam input
model.track(source=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       4 model = YOLO("yolo-Weights/yolov8n.pt")
#       6 # Start tracking objects in a video
#       7 # You can also use live video streams or webcam input
# ----> 8 model.track(source=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4")
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:602, in Model.track(self, source, stream, persist, **kwargs)
#     600 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     601 kwargs["mode"] = "track"
# --> 602 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:226, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     222     self.setup_model(model)
#     224 with self._lock:  # for thread-safe inference
#     225     # Setup source every time predict is called
# --> 226     self.setup_source(source if source is not None else self.args.source)
#     228     # Check if save_dir/ label file exists
#     229     if self.args.save or self.args.save_txt:
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.setup_source(self, source)
#     188 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     189 self.transforms = (
#     190     getattr(
#     191         self.model.model,
#    (...)
#     196     else None
#     197 )
# --> 198 self.dataset = load_inference_source(
#     199     source=source,
#     200     batch=self.args.batch,
#     201     vid_stride=self.args.vid_stride,
#     202     buffer=self.args.stream_buffer,
#     203 )
#     204 self.source_type = self.dataset.source_type
#     205 if not getattr(self, "stream", True) and (
#     206     self.source_type.stream
#     207     or self.source_type.screenshot
#     208     or len(self.dataset) > 1000  # many images
#     209     or any(getattr(self.dataset, "video_flag", [False]))
#     210 ):  # videos
#
# File ~\anaconda3\Lib\site-packages\ultralytics\data\build.py:202, in load_inference_source(source, batch, vid_stride, buffer)
#     200     dataset = LoadPilAndNumpy(source)
#     201 else:
# --> 202     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#     204 # Attach source types to the dataset
#     205 setattr(dataset, "source_type", source_type)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\data\loaders.py:312, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride)
#     310 self.bs = batch
#     311 if any(videos):
# --> 312     self._new_video(videos[0])  # new video
#     313 else:
#     314     self.cap = None
#
# File ~\anaconda3\Lib\site-packages\ultralytics\data\loaders.py:382, in LoadImagesAndVideos._new_video(self, path)
#     380 self.fps = int(self.cap.get(cv2.CAP_PROP_FPS))
#     381 if not self.cap.isOpened():
# --> 382     raise FileNotFoundError(f"Failed to open video {path}")
#     383 self.frames = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT) / self.vid_stride)
#
# FileNotFoundError: Failed to open video C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
