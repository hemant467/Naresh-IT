# %%
import nltk

# %%
#nltk.download()
# if you are already downloaded do not run agian

#------ if we want to install a specific package
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\omkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()

# %%
#print(text)
# we need to clean the data
# we need to divide into sentences or words
# we need to remove the spl charcters
# we need to convert every word to lower case
# we need to remove some stop words
#      a,an,the no importance
# extra space we want only alphabets,numericals etc

# %% [markdown]
# **Step-1: Tokenization**
#
# - Token means a piece of text that can be able to read
#
# - Token can be a word or a punctuation also can be token
#
# - Generally in NLP task we will remove punctuations
#
# - But in LLM model tasks we will not remove

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
# word_tokenize will divide into words
# sent_tokenize will divide into senetence 
# we can use string.split() ==== NLTK framework

# %%
words=word_tokenize(text)   # text.split()
words[:20]
# Out:
# ['One',
#  'morning',
#  ',',
#  'when',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'from',
#  'troubled',
#  'dreams',
#  ',',
#  'he',
#  'found',
#  'himself',
#  'transformed',
#  'in',
#  'his',
#  'bed',
#  'into',
#  'a']

# %%
# if we do with basic string methods
# it will not seperate the words and punctuation
# so better go with tokenization
text.split()[:5]
# Out:
# ['One', 'morning,', 'when', 'Gregor', 'Samsa']

# %% [markdown]
# **Step-2: Remove the punctuations**

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import re
pattern=f"[{re.escape(string.punctuation)}]"
print(pattern)
re.sub(pattern,'',"hello !")
# Out:
# [!"\#\$%\&'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~]
# 'hello '

# %%
re.sub(pattern,'',"hello !%# ho> @re you")
# Out:
# 'hello  ho re you'

# %%
import re
import string
from nltk.tokenize import word_tokenize,sent_tokenize
#================= Read the data ===================
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()
#================== Created a Regex pattern ==============
pattern=f"[{re.escape(string.punctuation)}]"
cleaned_text=re.sub(pattern,'',text)
#==================== Tokenize into words =================
words=word_tokenize(cleaned_text)

# %% [markdown]
# **Step-3:Lower The words**

# %%
words_lower=[word.lower() for word in words]

# %%
import re
import string
from nltk.tokenize import word_tokenize,sent_tokenize
#================= Read the data ===================
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()
#================== Created a Regex pattern ==============
pattern=f"[{re.escape(string.punctuation)}]"
cleaned_text=re.sub(pattern,'',text)
#==================== Tokenize into words =================
words=word_tokenize(cleaned_text)
#==================== Lower the words ======================
words_lower=[word.lower() for word in words]

# %%
words_lower
# Out:
# ['one',
#  'morning',
#  'when',
#  'gregor',
#  'samsa',
#  'woke',
#  'from',
#  'troubled',
#  'dreams',
#  'he',
#  'found',
#  'himself',
#  'transformed',
#  'in',
#  'his',
#  'bed',
#  'into',
#  'a',
#  'horrible',
#  'vermin',
#  'he',
#  'lay',
#  'on',
#  'his',
#  'armourlike',
#  'back',
#  'and',
#  'if',
#  'he',
#  'lifted',
#  'his',
#  'head',
#  'a',
#  'little',
#  'he',
#  'could',
#  'see',
#  'his',
#  'brown',
#  'belly',
#  'slightly',
#  'domed',
#  'and',
#  'divided',
#  'by',
#  'arches',
#  'into',
#  'stiff',
#  'sections',
#  'the',
#  'bedding',
#  'was',
#  'hardly',
#  'able',
#  'to',
#  'cover',
#  'it',
#  'and',
#  'seemed',
#  'ready',
#  'to',
#  'slide',
#  'off',
#  'any',
#  'moment',
#  'his',
#  'many',
#  'legs',
#  'pitifully',
#  'thin',
#  'compared',
#  'with',
#  'the',
#  'size',
#  'of',
#  'the',
#  'rest',
#  'of',
#  'him',
#  'waved',
#  'about',
#  'helplessly',
#  'as',
#  'he',
#  'looked',
#  'whats',
#  'happened',
# ...

# %% [markdown]
# **Step-4:Alphanumeric words**
#
# - we need alphabets numericals
#
# - any spaces still any unwanted characters

# %%
for words in ['','hello','123','hello123']:
    if words.isalnum():
        print(words)
# Out:
# hello
# 123
# hello123

# %%
# for words in ['','hello']:
#     if words.isalnum():
#         print(words)

words_alpha_num=[word for word in words_lower if word.isalnum()]

# %%
#words_alpha_num

# %%
import re
import string
from nltk.tokenize import word_tokenize,sent_tokenize
#================= Read the data ===================
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()
#================== Created a Regex pattern ==============
pattern=f"[{re.escape(string.punctuation)}]"
cleaned_text=re.sub(pattern,'',text)
#==================== Tokenize into words =================
words=word_tokenize(cleaned_text)
#==================== Lower the words ======================
words_lower=[word.lower() for word in words]
#================ Alpha numeric words ======================
words_alpha_num=[word for word in words_lower if word.isalnum()]

# %% [markdown]
# **Step-5:Stop words**
#
# Stop words are extremely common words, like "the," "a," and "is,"
# that are often removed from text
# during data processing because they carry little substantive meaning on their own

# %%
from nltk.corpus import stopwords

# %%
# nltk.download('stopwords')

# %%
stopwords.words('hinglish')
# Out:
# ['a',
#  'aadi',
#  'aaj',
#  'aap',
#  'aapne',
#  'aata',
#  'aati',
#  'aaya',
#  'aaye',
#  'ab',
#  'abbe',
#  'abbey',
#  'abe',
#  'abhi',
#  'able',
#  'about',
#  'above',
#  'accha',
#  'according',
#  'accordingly',
#  'acha',
#  'achcha',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'agar',
#  'ain',
#  'aint',
#  "ain't",
#  'aisa',
#  'aise',
#  'aisi',
#  'alag',
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'andar',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'ap',
#  'apan',
#  'apart',
#  'apna',
#  'apnaa',
#  'apne',
#  'apni',
#  'appear',
#  'are',
#  'aren',
#  'arent',
#  "aren't",
#  'around',
#  'arre',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'at',
#  'aur',
#  'avum',
#  'aya',
#  'aye',
# ...

# %%
stopwords.fileids()
# Out:
# ['albanian',
#  'arabic',
#  'azerbaijani',
#  'basque',
#  'belarusian',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'tamil',
#  'turkish']

# %%
#words_alpha_num
# if a word is stop word dont consider that
# for word in words_alpha_num:
#     if word not in stopwords.words('English'):
#         print(word)
eng_stop=stopwords.words('English')
tokens=[word for word in words_alpha_num if word not in eng_stop]
#tokens

# %%
import re
import string
from nltk.tokenize import word_tokenize,sent_tokenize
#================= Read the data ===================
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()
#================== Created a Regex pattern ==============
pattern=f"[{re.escape(string.punctuation)}]"
cleaned_text=re.sub(pattern,'',text)
#==================== Tokenize into words =================
words=word_tokenize(cleaned_text)
#==================== Lower the words ======================
words_lower=[word.lower() for word in words]
#=============== Stop words ===================================
eng_stop=stopwords.words('English')
tokens=[word for word in words_alpha_num if word not in eng_stop]
tokens
# Out:
# ['one',
#  'morning',
#  'gregor',
#  'samsa',
#  'woke',
#  'troubled',
#  'dreams',
#  'found',
#  'transformed',
#  'bed',
#  'horrible',
#  'vermin',
#  'lay',
#  'armourlike',
#  'back',
#  'lifted',
#  'head',
#  'little',
#  'could',
#  'see',
#  'brown',
#  'belly',
#  'slightly',
#  'domed',
#  'divided',
#  'arches',
#  'stiff',
#  'sections',
#  'bedding',
#  'hardly',
#  'able',
#  'cover',
#  'seemed',
#  'ready',
#  'slide',
#  'moment',
#  'many',
#  'legs',
#  'pitifully',
#  'thin',
#  'compared',
#  'size',
#  'rest',
#  'waved',
#  'helplessly',
#  'looked',
#  'whats',
#  'happened',
#  'thought',
#  'wasnt',
#  'dream',
#  'room',
#  'proper',
#  'human',
#  'room',
#  'although',
#  'little',
#  'small',
#  'lay',
#  'peacefully',
#  'four',
#  'familiar',
#  'walls',
#  'collection',
#  'textile',
#  'samples',
#  'lay',
#  'spread',
#  'table',
#  'samsa',
#  'travelling',
#  'salesman',
#  'hung',
#  'picture',
#  'recently',
#  'cut',
#  'illustrated',
# ...
