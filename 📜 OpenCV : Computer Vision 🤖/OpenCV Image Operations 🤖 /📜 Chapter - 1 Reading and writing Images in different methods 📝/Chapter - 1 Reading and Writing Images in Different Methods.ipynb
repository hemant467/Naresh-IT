# %%
import cv2

# first import the package:
# if you get the error: than install the package

# !pip install opencv-python

# when you want install throgh cmd: remove ! mark
#                                 : pip install <package_name>

# if you want install in jupyter notebook:  add the ! mark and run
#                                 : !pip install <package_name>

# %% [markdown]
# **Method-1**
#
# - Uing openCV method
#
# - Every image we have height and width
#
# - If it is a color image (h,w,c)
#
# - Color: R G B  (3)
#
# - If it is a color image  shape (h,w,3)
#
# - We have two kind of images will be available
#
#   - gray
#
#     - the values always varies between 0 and 1
#
#     - 0 means black  1 means white
#
#   - color
#
#     - VIBGYOR  :  2^7 = 128
#
#          - 0 to 255
#
#          - No color = Black: 0
#
#          - V+I+B+G+Y+O+R= white: 255
#
#
# - When you read Image, it will open a new window
#
# - And image will display on the window
#
# - If you want to close the window press :0

# %%
import os
os.getcwd()

#'./images/Benjamin-Franklin.jpg' # Relative path

#r'C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\OpenCV\images\Benjamin-Franklin.jpg' # Absolute path
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Naresh IT\\OpenCV\\Cv Basics'

# %% [markdown]
# **imread**
#
# - image read
#
# - always focus whe you load or load the image
#
# - the image load as a pixel of array
#
# - or image load as directly like an image
#
#     - using computer vision
#
#     - using pillow
#
#     - using kears

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#cv2.imshow("benjiman",image)
#image

# are you able to see image array pixel values
#

# %%
## All together  in local================
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#input1 = cv2.imread('./images/Benjamin-Franklin.jpg')
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#image

# %% [markdown]
# - when we read the image path with opencv it is a numpy array
#
# - we can show the image in two ways
#
#     - matplotlib: plt.imshow()
#
#     - opencv: cv2.imshow()

# %%
import cv2
import matplotlib.pyplot as plt
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
plt.imshow(image)

# %% [markdown]
# **Method-2**
#
# - Uing google colab notebook
#
# - Run below codes in Google colab only

# %%
# ============== In google colab=====================
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread("contents/Benjamin-Franklin.jpg")
cv2_imshow(image)

# at home
# upload the image 
# and Run above lines

# %% [markdown]
# **Method-3**
#
# - Using Pillow package

# %%
#============= by using Pillow it will open in another window=========================
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image.show() # open in new window its similar to laptop pictures

# %%
#=========================== remove the show and it will open in same notebook============================
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image #open in jupyter notebook
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x570>

# %% [markdown]
# **Method-4**
#
# - Open using matplotlib

# %%
#====================================== Read the image using Pillow and open the image using matplotlib==========
import matplotlib.pyplot as plt
# Open the image using pillow
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#show the image using matplotlib
plt.imshow(image)

# %%
#============= Read the image using cv2 and open By using matplotlib======================
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)  # BGR

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2

image_pil = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#show the image using matplotlib
plt.subplot(1,2,1).imshow(image_pil)
image_cv=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
plt.subplot(1,2,2).imshow(image_cv)  # BGR

# %%
# when we read the image using cv
# and will show using matplotlib
# the color appears in Blue by defualt cv read the image in BGR

#====================================== Read the image using Pillow and open the image using matplotlib==========
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %% [markdown]
# **Writing images**

# %%
import cv2
import numpy as np
from PIL import Image

image_cv=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image_pil = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
cv2.imwrite('output.jpg', image_cv) # less in kb
cv2.imwrite('output.png', np.array(image_pil)) # more in kb
# Out:
# True
