# %% [markdown]
# **Steps to capture a video:**
#
#
# - Use cv2.VideoCapture() to get a video capture object for the camera.
#
# - Video is a combination of frames
#
# - When we capture live video, it is like a infinite frames till we stop the video
#
# - Set up an infinite while loop and use the read() method to read the frames using the above created object.
#
# - Use cv2.imshow() method to show the frames in the video.
#
# - Breaks the loop when the user clicks a specific key.

# %%
import cv2
# cv2.imread : Image read
# cv2.imshow : Image show
# cv2.imwrite: Image write
cv2.VideoCapture(0)  # it will open the camera laptop. capture our videos
# Out:
# < cv2.VideoCapture 00000262D26A9B30>

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#input1 = cv2.imread('./images/Benjamin-Franklin.jpg')
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# import the opencv library 
import cv2 
  
# define a video capture object 
vid = cv2.VideoCapture(0) 
  
while True:    
    # Capture the video frame 
    # by frame 
    ret, frame = vid.read() 
    # ret= boolean value
    # ret=True, the frame is captured
    # ret=False , the frame is not capture
    print(ret)
    # Display the resulting frame 
    cv2.imshow('frame', frame)   
    # the 'q' button is set as the 
    # quitting button you may use any 
    # desired button of your choice
    # 1 means one milli second
    # 1 and 0xFF its try identify an 8 digit key
    # ord('q') : ASCII 8 digits
    # so it will check are you entered any 8 digit key or not
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
        
# After the loop release the cap object 
vid.release() 
# Destroy all the windows 
cv2.destroyAllWindows()
# Out:
# True

# %%
0xFF
0b11111111  # 8bits =1byte
# Out:
# 255

# %%
bin(ord('q'))
# Out:
# '0b1110001'

# %%
# import the opencv library 
import cv2 
vid = cv2.VideoCapture(0) 
  
while True:    
    ret, frame = vid.read()
    cv2.imshow('frame', frame)   
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
vid.release() 
cv2.destroyAllWindows()

# %%
# import cv2 
# vid = cv2.VideoCapture("los_angeles.mp4") 
  
# while True:    
#     ret, frame = vid.read()
#     cv2.imshow('frame', frame)   
#     if cv2.waitKey(1) & 0xFF == ord('q'): 
#         break
# vid.release() 
# cv2.destroyAllWindows()

# %%
import cv2 
vid = cv2.VideoCapture("los_angeles.mp4") 
  
while True:    
    ret, frame = vid.read() 
    if not ret:
        break
    cv2.imshow('frame', frame)   
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
vid.release() 
cv2.destroyAllWindows()

# %% [markdown]
# **Get the images from Video**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Naresh IT\\OpenCV\\Cv Basics'

# %% [markdown]
# - we can create our own directory or folder using python
#
# - below code checks the folder name with **data** not available
#
# - It will creates a folder with name **data**, where your python file location
#
# - So generally we have two type paths will be available
#
#     - Absolute path
#
#         - Absolute path means entire full location
#
#         - 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\OpenCV\\data\\'
#
#     - Relative path
#
#         - Relative path gives current working directory
#
#         - we already in till OpenCV folder
#
#         - So we can give after opencv directly : './data/

# %%
import os
if not os.path.exists('data'): 
    os.makedirs('data') 

# if directory not there then create otherwise dont create

# %%
name = './data/frame' + str(1) + '.jpg'
name
# Out:
# './data/frame1.jpg'

# %%
# Importing all necessary libraries 
import cv2 
import os 

# Read the video from specified path 
cam = cv2.VideoCapture("los_angeles.mp4")                # Web cam 

try: 
    # creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 

# frame 
currentframe = 0

while True: 
    # reading from frame 
    ret,frame = cam.read() 
    if ret: 
        # if video is still left continue creating images 
        name = './data/frame' + str(currentframe) + '.jpg'  #  inside data folder
        print ('Creating...' + name) 
        # writing the extracted images 
        cv2.imwrite(name, frame)
        cv2.imshow('image',frame)
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
        
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../data/frame0.jpg
# Creating..../data/frame1.jpg
# Creating..../data/frame2.jpg
# Creating..../data/frame3.jpg
# Creating..../data/frame4.jpg
# Creating..../data/frame5.jpg
# Creating..../data/frame6.jpg
# Creating..../data/frame7.jpg
# Creating..../data/frame8.jpg
# Creating..../data/frame9.jpg
# Creating..../data/frame10.jpg
# Creating..../data/frame11.jpg
# Creating..../data/frame12.jpg
# Creating..../data/frame13.jpg
# Creating..../data/frame14.jpg
# Creating..../data/frame15.jpg
# Creating..../data/frame16.jpg
# Creating..../data/frame17.jpg
# Creating..../data/frame18.jpg
# Creating..../data/frame19.jpg
# Creating..../data/frame20.jpg
# Creating..../data/frame21.jpg
# Creating..../data/frame22.jpg
# Creating..../data/frame23.jpg
# Creating..../data/frame24.jpg
# Creating..../data/frame25.jpg
# Creating..../data/frame26.jpg
# Creating..../data/frame27.jpg
# Creating..../data/frame28.jpg
# Creating..../data/frame29.jpg
# Creating..../data/frame30.jpg
# ...

# %% [markdown]
# # **Write a text on Video**

# %%
import cv2 
vid = cv2.VideoCapture(0) 
  
while True:    
    ret, frame = vid.read() 
    print(ret)
    cv2.imshow('frame', frame)   
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
vid.release()  
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
import cv2 
  
cap = cv2.VideoCapture(0) 
  
while(True): 
      
    # Capture frames in the video 
    ret, frame = cap.read() 
    # describe the type of font to be used. 
    font = cv2.FONT_HERSHEY_SIMPLEX 
    # Use putText() method for 
    # inserting text on video    R=0,G=255,B=255
    cv2.putText(frame, 'Hello Omkar', (50, 50), 
                font, 1,(0, 255, 255),
                5,cv2.LINE_4) 
  
    # Display the resulting frame 
    cv2.imshow('video', frame) 
  
    # creating 'q' as the quit  
    # button for the video 
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

# release the cap object 
cap.release() 
# close all windows 
cv2.destroyAllWindows()

# %%
import cv2
videopath = ("los_angeles.mp4")
cap = cv2.VideoCapture(videopath)
while True:
    ret, frame = cap.read()
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, 'car video', (50, 50),
                font, 1, (0,255,255), 2, cv2.LINE_4)
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
videopath = ("los_angeles.mp4")
cap = cv2.VideoCapture(videopath)
while True:
    ret, frame = cap.read()
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, 'car video', (50, 50),
                font, 1, (0,255,255), 2, cv2.LINE_4)
    cv2.rectangle(frame, 
                  (100, 100), 
                  (500, 500), 
                  (0, 255, 0), 
                  3)
    if not ret:break
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2 
  
def main(): 
    
    # reading the input 
    cap = cv2.VideoCapture(0) 
  
    output = cv2.VideoWriter( 
        "output.mp4", 
        cv2.VideoWriter_fourcc(*'XVID'), 
        30, # fps 
        (1080, 1920)) 
  
    while(True): 
        ret, frame = cap.read() 
        if(ret): 
              
            # adding rectangle on each frame 
            cv2.rectangle(frame, (100, 100), (500, 500), (0, 255, 0), 3)
            #pt1= Top left corner pt2= bottom right
              
            # writing the new frame in output 
            output.write(frame) 
            cv2.imshow("output", frame) 
            if cv2.waitKey(1) & 0xFF == ord('s'): 
                break
  
    cv2.destroyAllWindows() 
    output.release() 
    cap.release() 
  
  
if __name__ == "__main__": 
    main()

# %%
# 1) How to read the image
# 2) How to capture the video
# 3) How to divide into frames of the video file
# 4) How to write the text
# 5) How to draw a rectangle and save in to video writer

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Data science\\Batch-1_May3\\NLP\\Python codes'
