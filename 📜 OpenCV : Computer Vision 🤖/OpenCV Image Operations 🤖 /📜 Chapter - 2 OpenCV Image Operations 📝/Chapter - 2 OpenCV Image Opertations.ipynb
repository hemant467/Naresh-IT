# %%
import cv2

# first import the package:
# if you get the error: than install the package

# %%
# !pip install opencv-python

# when you want install throgh cmd: remove ! mark
#                                 : pip install <package_name>

# if you want install in jupyter notebook:  add the ! mark and run
#                                 : !pip install <package_name>

# %%
#pip uninstall opencv-python

# %% [markdown]
# **Read the image using OpenCV commnad**

# %%
import cv2
dir(cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'ALGO_HINT_ACCURATE',
#  'ALGO_HINT_APPROX',
#  'ALGO_HINT_DEFAULT',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
#  'Algorithm',
# ...

# %% [markdown]
# **Convert color image to Gray**

# %%
import cv2 
   
      
# Read the image 
image = cv2.imread('digits1.png') 
image.shape
# Out:
# (1000, 2000, 3)

# %%
import cv2
image = cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image.shape
# Out:
# (570, 547, 3)

# %% [markdown]
# **Convert Color image Gray**
#
# - Color image has RGB channel
#
# - Gray means Balck and White
#
# - **cvtColor**
#
# - OpenCV by default take as BGR channel
#
# - Inside we need to pass a Method  **BGR2GRAY**

# %%
import numpy as np 
import cv2 
         
# Read the image 
image = cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg") 
# gray scale conversion 
gray_img = cv2.cvtColor(image, 
                        cv2.COLOR_BGR2GRAY) 
RGB_img = cv2.cvtColor(image, 
                        cv2.COLOR_BGR2RGB)

# %%
gray_img.shape, image.shape
# image is colour 3 Dim
# gary is Black and while 2Dim
# Out:
# ((570, 547), (570, 547, 3))

# %%
import matplotlib.pyplot as plt
plt.subplot(1,3,1).imshow(image)
plt.subplot(1,3,2).imshow(gray_img)
plt.subplot(1,3,3).imshow(RGB_img)

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [244, 246, 246],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [240, 242, 242],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
gray_img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 246, 255, 255],
#        [255, 255, 255, ..., 242, 254, 254],
#        [255, 255, 255, ..., 242, 254, 254]], dtype=uint8)

# %%
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('gray_image', gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#In this section we load basic packages that will be used 
import cv2 as cv2
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
cv2.__version__
# Out:
# '4.8.1'

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [244, 246, 246],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [240, 242, 242],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
plt.imshow(image[110:140,200:300])

# %%
image[110:140,200:300]=[255,255,255]
# Out:
# array([[[  0,   5,  33],
#         [  1,  12,  40],
#         [ 11,  22,  50],
#         ...,
#         [ 41,  68, 112],
#         [ 61,  88, 132],
#         [ 80, 107, 151]],
#
#        [[  0,   0,  27],
#         [  0,   8,  37],
#         [ 16,  24,  53],
#         ...,
#         [ 35,  60, 102],
#         [ 58,  83, 127],
#         [ 81, 106, 148]],
#
#        [[  9,  11,  41],
#         [ 16,  18,  48],
#         [ 29,  31,  61],
#         ...,
#         [ 10,  32,  73],
#         [ 29,  51,  93],
#         [ 52,  74, 115]],
#
#        ...,
#
#        [[ 23,  25,  43],
#         [ 24,  28,  47],
#         [ 27,  31,  55],
#         ...,
#         [118, 139, 200],
#         [122, 143, 204],
#         [126, 147, 208]],
#
#        [[ 26,  30,  49],
#         [ 27,  33,  52],
#         [ 32,  38,  61],
#         ...,
#         [120, 141, 203],
#         [123, 144, 205],
#         [127, 148, 209]],
#
#        [[ 22,  25,  46],
#         [ 24,  29,  50],
#         [ 30,  35,  60],
# ...

# %%
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
## All together  in local================
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# ============== In google colab=====================
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread("contents/Benjamin-Franklin.jpg")
cv2_imshow(image)

#============= by using Pillow it will open in another window=========================
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image.show()

#=========================== remove the show and it will open in same notebook============================
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image

#============= Read the image using Pillow and open By using matplotlib======================
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

#====================================== Read the image using Pillow and open the image using matplotlib==========
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %%
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x570>

# %%
import PIL
dir(PIL)
# Out:
# ['ExifTags',
#  'Image',
#  'ImageMode',
#  'TiffTags',
#  'UnidentifiedImageError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_binary',
#  '_deprecate',
#  '_imaging',
#  '_plugins',
#  '_util']

# %%
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image.show()

# %%
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# gray scale conversion 
rgb_img = cv2.cvtColor(image, 
                        cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib


# gray scale conversion 
rgb_img = cv2.cvtColor(image, 
                        cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1).imshow(image)
plt.subplot(1,2,2).imshow(rgb_img)

# %%
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %%
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image

# Pixel values will get using open CV only
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [244, 246, 246],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [240, 242, 242],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
(height, width, channels)=image.shape

# %%
print ("Image height", height)
print ("Image width", width)
print ("Channels", channels)  # RGB, but it originally BGR
# Out:
# Image height 570
# Image width 547
# Channels 3

# %%
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# **Crop the image**
#
# - In the image we can select a particular part of the image
#
# - Image has pixels of rows and columns
#
# - slice around rows and slice around the column values of the image

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [244, 246, 246],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [240, 242, 242],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
image.shape
# Out:
# (570, 547, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
import cv2
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
cropped_image=image[100:120, 250:320]

# %%
import matplotlib.pyplot as plt
plt.imshow(cropped_image)

# %%
image[100:120, 250:320]
# Out:
# array([[[ 70, 103, 149],
#         [ 59,  92, 138],
#         [ 49,  82, 128],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        [[ 74, 107, 153],
#         [ 64,  97, 143],
#         [ 54,  87, 133],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        [[ 85, 118, 164],
#         [ 76, 109, 155],
#         [ 66,  99, 145],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        ...,
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [116, 142, 189],
#         ...,
#         [123, 149, 196],
#         [123, 149, 196],
#         [121, 149, 196]],
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [117, 143, 190],
#         ...,
#         [128, 154, 201],
#         [128, 154, 201],
#         [126, 154, 201]],
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [118, 144, 191],
# ...

# %% [markdown]
# - we already know that
#
# - 0 represents black
#
# - 255 or 1 represnts white
#
# - if some of the pixel value we are equating to 0
#
# - then that part of the shape become black

# %% [markdown]
# **Mask the image**

# %%
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %%
image[100:120, 250:320]
# [ 70, 103, 149]=[255,0,0]
# Out:
# array([[[ 70, 103, 149],
#         [ 59,  92, 138],
#         [ 49,  82, 128],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        [[ 74, 107, 153],
#         [ 64,  97, 143],
#         [ 54,  87, 133],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        [[ 85, 118, 164],
#         [ 76, 109, 155],
#         [ 66,  99, 145],
#         ...,
#         [119, 146, 190],
#         [119, 146, 190],
#         [119, 146, 190]],
#
#        ...,
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [116, 142, 189],
#         ...,
#         [123, 149, 196],
#         [123, 149, 196],
#         [121, 149, 196]],
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [117, 143, 190],
#         ...,
#         [128, 154, 201],
#         [128, 154, 201],
#         [126, 154, 201]],
#
#        [[116, 142, 189],
#         [115, 141, 188],
#         [118, 144, 191],
# ...

# %%
image[100:120, 250:320]=(30,70,100)  #   R+B= 
plt.imshow(image)

# (255,0,0):  Red
# (0,255,0): Green
# (0,0,255): Blue
# (255,255,255): White

# %%
olive=(128,128,0)
image[100:120, 250:320]=olive
plt.imshow(image)

# %% [markdown]
# - when we read the image using open cv
#
# - when we plot the image using matplotlib
#
# - we might have seen some blue color shade
#
# - Open Cv inherently takes BGR
#
# - so we need to convert BGR to RGB

# %%
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow 
image_bgr=cv2.imread("C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg")
#open the image using matplotlib
image_rgb= cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)
image_gray= cv2.cvtColor(image_bgr,cv2.COLOR_BGR2GRAY)
plt.subplot(1,3,1).imshow(image_bgr)
plt.subplot(1,3,2).imshow(image_rgb)
plt.subplot(1,3,3).imshow(image_gray)
plt.show()

# %%
#Routine to fix 
def fixColor(image):
    return(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
#Note the impact of the correct color scheme
plt.imshow(fixColor(image))

# %% [markdown]
# **warpAffine**
#
# - Is used to transform the images
#
# - Will transform the images along the horizontal way and along the vertical axis
#
# - 1,0  represents horizontal axis
#
# - 0,1 represents vertical axis

# %%
#Translation matrix the first row moves pixels horizontally and the second row moves in vertically.
import numpy as np
M = np.float32([[1, 0, 250], 
                [0, 1, 500]])
M

# 1 0  is horizontal axis
# 0 1  is vertical axis
# Out:
# array([[  1.,   0., 250.],
#        [  0.,   1., 500.]], dtype=float32)

# %%
shifted = cv2.warpAffine(image, 
                         M, 
                         (image.shape[1], image.shape[0]))
plt.imshow(shifted)

# %%
#Changed the pixel directions to move image left and up
#[1, 0, -50] [row,column,number of pixels]
M = np.float32([[1, 0, -50],   # Horizontal move 
                [0, 1, -100]]) # Vertical move
shifted = cv2.warpAffine(image, 
                         M, 
                         (image.shape[1], 
                          image.shape[0]))
plt.imshow(shifted)

# %% [markdown]
# **Image Rotation**

# %%
(height, width, channels) = image.shape
center=(width//2, height//2)
center
# Out:
# (273, 285)

# %%
M = cv2.getRotationMatrix2D(center, 45, 1.0)
M
# Out:
# array([[   0.70710678,    0.70710678, -121.5655839 ],
#        [  -0.70710678,    0.70710678,  276.51471863]])

# %%
M = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated = cv2.warpAffine(image, M, (width, height))
plt.imshow(rotated)

# %%
M = cv2.getRotationMatrix2D(centre, 90, 1.0)
rotated = cv2.warpAffine(image, M, (width, height))
plt.imshow(rotated)

# %%
M = cv2.getRotationMatrix2D(centre, 180, 1.0)
rotated = cv2.warpAffine(image, M, (width, height))
plt.imshow(rotated)

# %%
M = cv2.getRotationMatrix2D(centre, -90, 1.0)
rotated = cv2.warpAffine(image, M, (width, height))
plt.imshow(rotated)

# %% [markdown]
# **Resizing**

# %%
image.shape[0] ,image.shape[1] # W
image.shape
# Out:
# (570, 547, 3)

# %%
r = 150.0 / image.shape[0]
r,image.shape[1]

# 150 is the width I have taken
# Now I want to know how much 150 is the percentage of original height
# 27%

# So I need to take 27% of Height also
# image.shape[0] * r
# Out:
# (0.2631578947368421, 547)

# %%
dim = (150, int(image.shape[1] * r))
dim
# Out:
# (150, 143)

# %%
#Here we resize setting width to 150 and scale the height accordingly
# interploation is a method to downsampling the image
# resize the image === > shrinkage 
# INTER_AREA is the method
r = 150.0 / image.shape[1]
dim = (150, int(image.shape[0] * r))
resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized)

# %%
image.shape
# Out:
# (570, 547, 3)

# %%
dim=(50,47)
resized = cv2.resize(image, dim)
plt.imshow(resized)

# %%
resized_1 = cv2.resize(resized,(300,300))
plt.imshow(resized_1)

# %%
resized_1 = cv2.resize(image,(4096,4096))
plt.imshow(resized_1)

# %%
#Here we rezise setting height to 150 and scale the width accordingly
r = 150.0 / image.shape[0]
dim = ( int(image.shape[1] * r), 150)
resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized)

# %%
cv2.imwrite('benziman_resize.png', image)

# %% [markdown]
# **Flipping**

# %%
#Flipping acros y-axis
flipped = cv2.flip(image, 1)
plt.imshow(flipped)

# %%
#flipping along x-axis
flipped = cv2.flip(image, 0)
plt.imshow(flipped)

# %%
#flipping along x and y axes
flipped = cv2.flip(image, -1)
plt.imshow(flipped)

# %% [markdown]
# **Cropping**
#
# We will now see an example of cropping the image to get the head only

# %%
image.shape

# %%
cropped_image=image[50:400, 250:400]
plt.imshow(cropped_image)

# %%
#Create a new video stream and get total frame count
video_stream = cv2.VideoCapture('images/faces.mp4')
total_frames=video_stream.get(cv2.CAP_PROP_FRAME_COUNT)
total_frames
# Out:
# 0.0

# %%
- In output layer

    - For regression
    
    - Binary classification
    
    - For Multi classification

- In Hidden layer 

- When we wil use Tanh(Zero centetred)

- what is the difference between ReLU and LeakyReLU

# %%
i=cv2.rectangle(image,
              (100,250),
              (250,400),
             (0,255,0),
             5)
plt.imshow(i)
#cv.rectangle(img,(384,0),(510,128),(0,255,0),3)
