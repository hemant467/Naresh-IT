# %% [markdown]
# <center><h1><b> Open CV for Gen AI Workshop </b></h1></center>
# <center><h2>By Mr.Omkar Sir</h2></center>

# %% [markdown]
# # Open CV Session - 2
# <center><h1><b>Open CV Session - 2</b></h1></center>
# <center><h3><b>cv - Computer Vision</b></h3></center>

# %% [markdown]
# Step - 1 : Install the required packages
#
# Package name : opencv-python

# %%
# !pip install opencv-python

# %% [markdown]
# Step - 2 : Import the packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Step - 3 : Read and show the image

# %% [markdown]
# * In-order to read the image, the image should be uploaded here

# %%
dir(cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'ALGO_HINT_ACCURATE',
#  'ALGO_HINT_APPROX',
#  'ALGO_HINT_DEFAULT',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AffineTransformer',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
# ...

# %%
cv2.imread('/content/70e8b246527f88131a5ea00ac3eced84.jpg')
# Out:
# array([[[134, 110,  80],
#         [114,  90,  60],
#         [ 70,  48,  20],
#         ...,
#         [ 83,  41,  12],
#         [100,  56,  25],
#         [100,  56,  25]],
#
#        [[ 50,  26,   0],
#         [ 68,  44,  14],
#         [ 68,  46,  18],
#         ...,
#         [ 97,  55,  26],
#         [103,  59,  30],
#         [ 94,  50,  19]],
#
#        [[ 63,  39,   9],
#         [ 55,  31,   1],
#         [ 46,  24,   0],
#         ...,
#         [ 88,  48,  19],
#         [ 88,  46,  17],
#         [ 80,  38,   9]],
#
#        ...,
#
#        [[ 12,  14,  14],
#         [  7,   9,   9],
#         [  3,   5,   5],
#         ...,
#         [ 25,  25,  25],
#         [ 23,  23,  23],
#         [ 18,  18,  18]],
#
#        [[ 15,  15,  15],
#         [ 10,  10,  10],
#         [  6,   5,   7],
#         ...,
#         [ 24,  24,  24],
#         [ 22,  22,  22],
#         [ 17,  17,  17]],
#
#        [[ 14,  14,  14],
#         [ 10,  10,  10],
#         [  8,   7,   9],
# ...

# %%
image=cv2.imread('/content/70e8b246527f88131a5ea00ac3eced84.jpg')

# %%
cv2_imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
image.shape

# height = 1080  = ROWS
# width  = 1920  = COLUMN
# color channel = 3 color image BGR
# Out:
# (1080, 1920, 3)

# %%
image
# Out:
# array([[[134, 110,  80],
#         [114,  90,  60],
#         [ 70,  48,  20],
#         ...,
#         [ 83,  41,  12],
#         [100,  56,  25],
#         [100,  56,  25]],
#
#        [[ 50,  26,   0],
#         [ 68,  44,  14],
#         [ 68,  46,  18],
#         ...,
#         [ 97,  55,  26],
#         [103,  59,  30],
#         [ 94,  50,  19]],
#
#        [[ 63,  39,   9],
#         [ 55,  31,   1],
#         [ 46,  24,   0],
#         ...,
#         [ 88,  48,  19],
#         [ 88,  46,  17],
#         [ 80,  38,   9]],
#
#        ...,
#
#        [[ 12,  14,  14],
#         [  7,   9,   9],
#         [  3,   5,   5],
#         ...,
#         [ 25,  25,  25],
#         [ 23,  23,  23],
#         [ 18,  18,  18]],
#
#        [[ 15,  15,  15],
#         [ 10,  10,  10],
#         [  6,   5,   7],
#         ...,
#         [ 24,  24,  24],
#         [ 22,  22,  22],
#         [ 17,  17,  17]],
#
#        [[ 14,  14,  14],
#         [ 10,  10,  10],
#         [  8,   7,   9],
# ...

# %% [markdown]
# # Convert into Gray scale:
#
# *   cv2.imread == read the image
# *   cv2.imshow == show the image
#
# To convert one image to another image
#
# cv2.cvtColor

# %%
cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
# Out:
# array([[104,  84,  42, ...,  37,  52,  52],
#        [ 21,  38,  40, ...,  51,  55,  46],
#        [ 33,  25,  19, ...,  44,  42,  34],
#        ...,
#        [ 14,   9,   5, ...,  25,  23,  18],
#        [ 15,  10,   6, ...,  24,  22,  17],
#        [ 14,  10,   8, ...,  19,  17,  11]], dtype=uint8)

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab.patches import cv2_imshow
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow
hls_image=cv2.cvtColor(image,cv2.COLOR_BGR2HLS)
cv2_imshow(hls_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab.patches import cv2_imshow
hsv_image=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# We have 3 images :
#
# *   image - BGR
# *   gray_image - Black and white
# *   rgb_image - RGB
# *   hsv_image - Thresholding

# %%
image.shape

# 1080  1920  : Rectangular box
#  200   200  : (200,200)
# Out:
# (1080, 1920, 3)

# %% [markdown]
# # Resized :

# %%
resized_image=cv2.resize(image,(200,200))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
resized_image=cv2.resize(image,(200,100))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>

# %% [markdown]
# # Cropping :
#
# *   Cropping means selecting a part of image
#
# *   image means pixels number
#
# *   Select any number and check which part is extracting
#
# *   Height  and width are there
#
# Height - 1080  || Width - 1920
#
# *   Height ranges from 0 to 1079
#
# *   Width ranges from 0 to 1919
#
# Suppose we want
#
# * height : [ 50:200 ]
# * width  : [ 50:200 ]

# %%
image[50:200,50:200]
# Out:
# array([[[ 52,  21,   0],
#         [ 64,  33,   2],
#         [ 60,  30,   3],
#         ...,
#         [ 80,  51,  20],
#         [ 91,  60,  27],
#         [ 78,  48,  13]],
#
#        [[ 92,  61,  30],
#         [ 72,  40,  11],
#         [ 52,  22,   0],
#         ...,
#         [ 68,  37,   4],
#         [ 74,  44,   9],
#         [ 57,  27,   0]],
#
#        [[111,  81,  52],
#         [ 77,  47,  18],
#         [ 58,  28,   1],
#         ...,
#         [ 76,  43,  10],
#         [ 80,  48,  13],
#         [104,  72,  36]],
#
#        ...,
#
#        [[ 98,  70,  36],
#         [ 92,  65,  31],
#         [ 83,  55,  24],
#         ...,
#         [ 89,  56,  23],
#         [ 85,  51,  21],
#         [ 91,  57,  27]],
#
#        [[ 89,  58,  25],
#         [ 89,  61,  27],
#         [ 85,  57,  23],
#         ...,
#         [119,  84,  51],
#         [ 59,  23,   0],
#         [ 85,  49,  19]],
#
#        [[ 77,  46,  13],
#         [ 76,  45,  12],
#         [ 79,  48,  15],
# ...

# %%
cropped=image[50:200,50:200]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
cropped=image[200:300,90:200]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=110x100>

# %%
cropped=image[700:900]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x200>

# %%
cropped=image[760:900]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x140>

# %%
cropped=image[800:900]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x100>

# %%
cropped=image[600:900]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x300>

# %% [markdown]
# # Flip the image :

# %%
cv2.flip(image,0)
# Out:
# array([[[ 14,  14,  14],
#         [ 10,  10,  10],
#         [  8,   7,   9],
#         ...,
#         [ 19,  19,  19],
#         [ 17,  17,  17],
#         [ 11,  11,  11]],
#
#        [[ 15,  15,  15],
#         [ 10,  10,  10],
#         [  6,   5,   7],
#         ...,
#         [ 24,  24,  24],
#         [ 22,  22,  22],
#         [ 17,  17,  17]],
#
#        [[ 12,  14,  14],
#         [  7,   9,   9],
#         [  3,   5,   5],
#         ...,
#         [ 25,  25,  25],
#         [ 23,  23,  23],
#         [ 18,  18,  18]],
#
#        ...,
#
#        [[ 63,  39,   9],
#         [ 55,  31,   1],
#         [ 46,  24,   0],
#         ...,
#         [ 88,  48,  19],
#         [ 88,  46,  17],
#         [ 80,  38,   9]],
#
#        [[ 50,  26,   0],
#         [ 68,  44,  14],
#         [ 68,  46,  18],
#         ...,
#         [ 97,  55,  26],
#         [103,  59,  30],
#         [ 94,  50,  19]],
#
#        [[134, 110,  80],
#         [114,  90,  60],
#         [ 70,  48,  20],
# ...

# %%
flip_v=cv2.flip(image,0)
cv2_imshow(flip_v)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
flip_h=cv2.flip(image,1)
cv2_imshow(flip_h)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
flip_h=cv2.flip(image,0)
flip_v=cv2.flip(image,1)

cv2_imshow(flip_v)
cv2_imshow(flip_h)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
flip_h=cv2.flip(image,0)
flip_v=cv2.flip(image,1)
flip_hv=cv2.flip(image,-1)

cv2_imshow(flip_v)
cv2_imshow(flip_h)
cv2_imshow(flip_hv)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
