# %% [markdown]
# <h1><center>LangSmith</center></h1>
# <h1><center>LangSmith</center>
# <center><b>From Prompt to Production</b></center>

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/providers/groq

# %% [markdown]
# https://smith.langchain.com/o/1a1170d3-ddd1-46c3-b49e-628e8d7dd745/projects
#
# https://reference.langchain.com/python/langchain_core/output_parsers/#langchain_core.output_parsers
#
# https://console.groq.com/playground
#
# https://groq.com/
#
# https://openrouter.ai/rankings
#
# https://docs.langchain.com/oss/python/integrations/chat/groq
#
# https://docs.langchain.com/oss/python/integrations/providers/groq

# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 6.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Chat Models

# %%
from langchain_groq import ChatGroq

# %% [markdown]
# ChatGroq is a method to access the llm model using API key
#
# chatgroq(
#     apikey,
#     model name,
#     temperature  # Model thinking power 0 - Straight answer ; 1 - Model thinking
#
# )

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat/groq

# %% [markdown]
# Model Llama 3.3 70B
# - llama-3.3-70b-versatile

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=50,
    # other params...
)

# %%
llm.invoke('Who are the top 5 cricketers in INDIA ?')
# Out:
# AIMessage(content='Here are the top 5 cricketers in India, based on their recent performances and overall impact on the game:\n\n1. **Virat Kohli**: Regarded by many as one of the greatest batsmen of all time, Kohli is', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 48, 'total_tokens': 98, 'completion_time': 0.120573024, 'completion_tokens_details': None, 'prompt_time': 0.001439207, 'prompt_tokens_details': None, 'queue_time': 0.0423943, 'total_time': 0.122012231}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--e8c1be18-2941-4073-9af8-ff1cd6125285-0', usage_metadata={'input_tokens': 48, 'output_tokens': 50, 'total_tokens': 98})

# %%
llm.invoke('Tell me about a guy named Hemant Katta')
# Out:
# AIMessage(content="I couldn't find any information on a person named Hemant Katta. It's possible that Hemant Katta is a private individual and not a public figure, or he may not have a significant online presence. If you could provide more context or", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 45, 'total_tokens': 95, 'completion_time': 0.090985895, 'completion_tokens_details': None, 'prompt_time': 0.002217606, 'prompt_tokens_details': None, 'queue_time': 0.042252237, 'total_time': 0.093203501}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--8a469ead-ae0c-4b9e-b1f8-908641342481-0', usage_metadata={'input_tokens': 45, 'output_tokens': 50, 'total_tokens': 95})

# %%
llm.invoke('Who are the top 5 cricketers in INDIA ?').content
# Out:
# 'Here are the top 5 cricketers in India, based on their recent performances and overall impact on the game:\n\n1. **Virat Kohli**: Regarded by many as one of the greatest batsmen of all time, Kohli is'

# %% [markdown]
# Controlled model with 50 tokens so till "Kohli is"

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None,
    # other params...
)

# %%
llm.invoke('Who are the top 5 cricketers in INDIA ?').content
# Out:
# "Here are the top 5 cricketers in India, based on their recent performances and overall impact on the game:\n\n1. **Virat Kohli**: Regarded by many as one of the greatest batsmen of all time, Kohli is the current captain of the Indian cricket team. He has been in phenomenal form, scoring runs consistently across all formats of the game.\n2. **Rohit Sharma**: A highly skilled opening batsman, Rohit is known for his elegant strokeplay and ability to score big hundreds. He is also an excellent leader, having led the Mumbai Indians to multiple IPL titles.\n3. **Jasprit Bumrah**: A pace bowler with a unique action, Bumrah has become one of the most feared bowlers in world cricket. He has been instrumental in India's success in recent years, taking wickets consistently in all formats of the game.\n4. **Ravindra Jadeja**: An all-rounder with exceptional skills, Jadeja is a vital cog in the Indian team. He is a talented batsman, a brilliant fielder, and a more-than-useful left-arm spinner.\n
# ...

# %%
print(llm.invoke('Who are the top 5 cricketers in INDIA ?').content)
# Out:
# Here are the top 5 cricketers in India, based on their recent performances and overall impact on the game:
#
# 1. **Virat Kohli**: Regarded by many as one of the greatest batsmen of all time, Kohli is the current captain of the Indian cricket team. He has been in phenomenal form, scoring runs consistently across all formats of the game.
# 2. **Rohit Sharma**: A highly skilled opening batsman, Rohit is known for his elegant strokeplay and ability to score big hundreds. He is also an excellent leader, having led the Mumbai Indians to multiple IPL titles.
# 3. **Jasprit Bumrah**: A pace bowler with a unique action, Bumrah has become one of the most feared bowlers in world cricket. He has been instrumental in India's success in recent years, taking wickets consistently in all formats of the game.
# ...

# %%
llm.invoke('Who are the top 5 cricketers in INDIA ?').content
# Out:
# "Here are the top 5 cricketers in India, based on their recent performances and overall impact on the game:\n\n1. **Virat Kohli**: Regarded by many as one of the greatest batsmen of all time, Kohli is the current captain of the Indian cricket team. He has been in phenomenal form, scoring runs consistently across all formats of the game.\n2. **Rohit Sharma**: A highly skilled opening batsman, Rohit is known for his elegant strokeplay and ability to score big hundreds. He is also an excellent leader, having led the Mumbai Indians to multiple IPL titles.\n3. **Jasprit Bumrah**: A pace bowler with a unique action, Bumrah has become one of the most feared bowlers in world cricket. He has been instrumental in India's success in recent years, taking wickets consistently in all formats.\n4. **Ravindra Jadeja**: An all-rounder with exceptional skills, Jadeja is a vital cog in the Indian team. He is a talented batsman, a brilliant fielder, and a more-than-useful left-arm spinner.\n5. **KL Rahu
# ...

# %%
# !pip install langchain-core

# %%
import langchain_core

# %%
dir(langchain_core)
# Out:
# ['VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_api',
#  '_import_utils',
#  'caches',
#  'callbacks',
#  'env',
#  'exceptions',
#  'globals',
#  'language_models',
#  'load',
#  'messages',
#  'output_parsers',
#  'outputs',
#  'prompt_values',
#  'rate_limiters',
#  'runnables',
#  'surface_langchain_beta_warnings',
#  'surface_langchain_deprecation_warnings',
#  'tools',
#  'tracers',
#  'utils',
#  'version']

# %%
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# - We'll ask the question to llama model
# - Answer not cleaned
# - It'll go to Parser

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
chain.invoke('Tell about a poem on kid')
# Out:
# 'Here\'s a short poem about a kid:\n\n"A Little Bundle of Joy"\n\nWith eyes so bright and a smile so wide,\nA little kid runs, with energy inside.\nTheir laughter echoes, contagious and free,\nA bundle of joy, for you and me.\n\nTheir tiny hands, so small and new,\nGrasp yours tightly, with a love so true.\nTheir curious mind, with questions so bright,\nExplores the world, with wonder and delight.\n\nWith every step, they take with glee,\nA new discovery, for them to see.\nTheir imagination, runs wild and free,\nA magical world, for them to be.\n\nThis little kid, with a heart so pure,\nBrings joy to all, with their presence so sure.\nTheir smile can light, up a darkest night,\nAnd fill our hearts, with love and delight.\n\nThis poem celebrates the innocence and curiosity of a child, and the joy they bring to our lives. It highlights their energy, imagination, and love, and how they can light up our world with their presence.'

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
response=chain.invoke('Tell about a poem on kid')

print(response)
# Out:
# Here's a short poem about a kid:
#
# "A Little Bundle of Joy"
#
# With eyes so bright and a smile so wide,
# A little kid runs, with energy inside.
# Their laughter echoes, contagious and free,
# A bundle of joy, for you and me.
#
# Their tiny hands, so small and new,
# Grasp yours tightly, with a love so true.
# Their curious mind, with questions so bright,
# Explores the world, with wonder and delight.
#
# With every step, they take with glee,
# A new discovery, for them to see.
# Their imagination, runs wild and free,
# A magical world, for them to be.
#
# This little kid, with a heart so pure,
# Brings joy to all, with their presence so sure.
# Their innocence, and love so true,
# Make them a treasure, for me and you.
#
# This poem celebrates the joy and wonder of childhood, and the magic that kids bring to our lives. It's a heartwarming tribute to the innocence and curiosity of children, and the love and happiness they bring to those around them.

# %%
chain=llm|parser
response=chain.invoke('Tell about a horror story')

print(response)
# Out:
# Here's a chilling horror story for you:
#
# The small town of Ravenswood was never the same after the night the children disappeared. It started with little Timmy, who was playing in his backyard when he vanished into thin air. His parents searched for him everywhere, but he was nowhere to be found.
#
# The next day, two more children went missing: Emily and Ben. They were last seen walking home from school, but they never made it. The town was in a state of panic as the search parties combed the woods and streets, but there was no sign of the children.
#
# As the days went by, more and more children disappeared. The town was gripped with fear, and no one knew what was happening to the kids. Some said it was a serial killer, while others believed it was something supernatural.
#
# ...

# %%
chain=llm|parser
response=chain.invoke('Tell about a bed time story')

print(response)
# Out:
# Once upon a time, in a land far, far away, there was a magical kingdom hidden behind a veil of sparkling stars. The kingdom was called Dreamland, and it was a place where dreams came alive.
#
# In the heart of Dreamland, there was a beautiful forest filled with towering trees that shone like diamonds in the moonlight. The trees were home to a group of friendly creatures called the Lullabies. The Lullabies were small, mischievous beings with wings as soft as feathers and hair as bright as the sun.
#
# Every night, the Lullabies would gather at the edge of the forest to sing a special song. The song was called the Lullaby of Dreams, and it had the power to bring sweet dreams to children all around the world.
#
# ...

# %% [markdown]
# What ever we did that we want to store & want to check later i.e Langsmith
# - How many question we asked

# %% [markdown]
# https://smith.langchain.com/o/1a1170d3-ddd1-46c3-b49e-628e8d7dd745?paginationModel=%7B%22pageIndex%22%3A0%2C%22pageSize%22%3A5%7D

# %%
LANGCHAIN_API_KEY="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"
LANGCHAIN_PROJECT="Testing LLM Application"

# %%
# Creating Environmental Variable
import os
os.environ["LANGCHAIN_API_KEY"]=LANGCHAIN_API_KEY
os.environ["LANGCHAIN_PROJECT"]=LANGCHAIN_PROJECT
os.environ["LANGCHAIN_TRACING_V2"]='true'

# What ever we do in this it is visible in LangSmith

from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
response=chain.invoke('Tell about a poem on kid')

print(response)
# Out:
# Here's a short poem about a kid:
#
# "A Little Bundle of Joy"
#
# With eyes so bright and a smile so wide,
# A little kid runs, with energy inside.
# Their laughter echoes, contagious and free,
# A bundle of joy, for you and me.
#
# Their tiny hands, so small and new,
# Grasp yours tightly, with a love so true.
# Their curious mind, with questions so bright,
# Explores the world, with wonder and delight.
#
# With every step, they take with glee,
# A new discovery, for them to see.
# Their imagination, runs wild and free,
# A magical world, for them to be.
#
# This little kid, with a heart so pure,
# Brings joy to all, with their presence so sure.
# Their innocence, and love so true,
# Make them a treasure, for me and you.
#
# This poem celebrates the joy and wonder of childhood, and the magic that kids bring to our lives. It's a heartwarming tribute to the innocence and curiosity of children, and the love and happiness they bring to those around them.

# %%
# Creating Environmental Variable
import os
os.environ["LANGCHAIN_API_KEY"]=LANGCHAIN_API_KEY
os.environ["LANGCHAIN_PROJECT"]=LANGCHAIN_PROJECT
os.environ["LANGCHAIN_TRACING_V2"]='true'

# What ever we do in this it is visible in LangSmith

from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
response=chain.invoke('Tell a horror story')

print(response)
# Out:
# The old mansion had been abandoned for decades, its grandeur and beauty slowly being consumed by the passing of time. The once-lush gardens were overgrown with weeds, the sound of crickets and the rustling of leaves the only signs of life.
#
# As I stepped inside, a chill ran down my spine. The air was thick with the scent of decay and rot. I had always been drawn to the supernatural and the occult, and this mansion was rumored to be one of the most haunted places in the country.
#
# I began to explore, my footsteps echoing off the walls. Every step creaked and groaned, as if the house itself was protesting my presence. I wandered from room to room, each one filled with the remnants of a life long past. Dust-covered furniture, faded portraits, and yellowed letters scattered across the floor.
#
# ...

# %%
LANGCHAIN_API_KEY="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"
LANGCHAIN_PROJECT="Workshop"

# %%
# Creating Environmental Variable
import os
os.environ["LANGSMITH_API_KEY"]="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"
os.environ["LANGSMITH_PROJECT"]="Workshop"
os.environ["LANGSMITH_TRACING_V2"]='true'

# What ever we do in this it is visible in LangSmith

from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
response=chain.invoke('Tell a horror story')

print(response)
# Out:
# The old mansion had been abandoned for decades, its grandeur and beauty slowly being consumed by the passing of time. The once-lush gardens were overgrown with weeds, the sound of crickets and the rustling of leaves the only signs of life.
#
# As I stepped inside, a chill ran down my spine. The air was thick with the scent of decay and rot. I had always been drawn to the supernatural and the occult, and this mansion was rumored to be one of the most haunted places in the country.
#
# I began to explore, my footsteps echoing off the walls. Every step creaked and groaned, as if the house itself was protesting my presence. I wandered from room to room, taking in the faded opulence and the remnants of a long-forgotten life.
#
# ...

# %%
# Creating Environmental Variable
import os
os.environ["LANGSMITH_API_KEY"]="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"
os.environ["LANGSMITH_PROJECT"]="Workshop"
os.environ["LANGSMITH_TRACING_V2"]='true'

# What ever we do in this it is visible in LangSmith

from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser=StrOutputParser()

chain=llm|parser
response=chain.invoke('Tell a horror story')

print(response)
