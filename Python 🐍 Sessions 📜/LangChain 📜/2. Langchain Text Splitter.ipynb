# %% [markdown]
# https://python.langchain.com/v0.1/docs/modules/data_connection/document_transformers/recursive_text_splitter/

# %%
# !pip install -qU langchain-text-splitters # it will not print quit upgarde
# !pip install langchain   # No updated package
# !pip install -U langchain-community # update the package

# %%
from langchain.document_loaders import TextLoader
file_path='GenAI.txt'
loader = TextLoader(file_path)
# Load the documents
documents = loader.load()

# %% [markdown]
# ## CharacterTextSplitter
#
# **Basic Functionality:**
#
#  This splitter divides the text into chunks based solely on a character limit, regardless of natural text boundaries like sentences or paragraphs.
#
# **Use Case:** It's suitable for simple scenarios where splitting the text by a fixed number of characters is sufficient, and you don't care about splitting within words or sentences.
#
# **Key Parameters:**
#
# - chunk_size: The maximum number of characters in each chunk.
#
# - chunk_overlap: The number of characters that should overlap between consecutive chunks.
#
# **How It Works:**
#  It will take the input text and split it into parts by counting characters. It does not consider word boundaries, sentences, or paragraphs. This can lead to splits in awkward places, like the middle of a word or sentence.

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text_splitter=CharacterTextSplitter(chunk_size=20,chunk_overlap=2)

# %%
docs=text_splitter.split_documents(documents)
len(docs)
# Out:
# 1

# %%
docs
# Out:
# [Document(metadata={'source': 'GenAI.txt'}, page_content='Generative artificial intelligence is artificial intelligence capable of generating text, images, videos, or other data using generative models, often in response to prompts. Generative AI models learn the patterns and structure of their input training data and then generate new data that has similar characteristics.')]

# %%
text_splitter=CharacterTextSplitter(separator=' ',chunk_size=20,chunk_overlap=2)
docs=text_splitter.split_documents(documents)
len(docs)
# Out:
# 20

# %%
docs
# Out:
# [Document(metadata={'source': 'GenAI.txt'}, page_content='Generative'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='artificial'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='intelligence is'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='is artificial'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='intelligence capable'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='of generating text,'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='images, videos, or'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='or other data using'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='generative models,'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='often in response to'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='to prompts.'),
#  Document(metadata={'source': 'GenAI.txt'}, page_content='Generative AI models'),
# ...

# %%
from langchain.document_loaders import TextLoader
file_path='/content/chatbot.txt'
loader = TextLoader(file_path)
# Load the documents
documents = loader.load()
documents

# %%
text_splitter=CharacterTextSplitter(chunk_size=1000,chunk_overlap=100)
docs=text_splitter.split_documents(documents)
len(docs)

# %%
len(docs[0].page_content)

# %%
[len(i.page_content) for i in docs]

# %%
text_splitter=CharacterTextSplitter(separator=' ',chunk_size=1000,chunk_overlap=100)
docs=text_splitter.split_documents(documents)
len(docs)

# %% [markdown]
# ## Recursive Text splitter

# %% [markdown]
# **RecursiveCharacterTextSplitter**
#
# **Advanced Functionality:** This splitter splits the text recursively, starting with larger, more meaningful units like paragraphs, then working down to sentences, and then words if necessary. It aims to split at natural language boundaries when possible.
#
# **Use Case:** This is ideal when you want more readable chunks that preserve the integrity of sentences and paragraphs, but still need to adhere to a character or token limit. It's more flexible and avoids cutting off in the middle of words or sentences.
#
# **Key Parameters:**
#
# - chunk_size: The maximum number of characters in each chunk.
#
# - chunk_overlap: The number of characters that should overlap between consecutive chunks.
#
# - separators: A list of characters used to separate text (e.g., paragraphs, sentences).
#
# **How It Works:** It tries to split the text using the largest units first, like paragraphs or sentences. If the text is still too large after splitting by these larger units, it recursively splits the text down to smaller units like individual words, ensuring cleaner splits.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter= RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=100)
docs=text_splitter.split_documents(documents)
len(docs)
# Out:
# 1

# %%
[len(i.page_content) for i in docs]

# %%
from langchain.text_splitter import CharacterTextSplitter

text = "This is a simple example text to demonstrate character-based splitting."
splitter = CharacterTextSplitter(chunk_size=10, chunk_overlap=5)
chunks = splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")
# Out:
# Chunk 1: This is a simple example text to demonstrate character-based splitting.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

#text = "LangChain is an awesome framework. It helps developers work with large language models. It supports modular components."
text = "This is a simple example text to demonstrate character-based splitting."
splitter = RecursiveCharacterTextSplitter(chunk_size=10, chunk_overlap=5)
chunks = splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")
# Out:
# Chunk 1: This is a
# Chunk 2: a simple
# Chunk 3: example
# Chunk 4: text to
# Chunk 5: demonstra
# Chunk 6: nstrate
# Chunk 7: character
# Chunk 8: acter-base
# Chunk 9: -based
# Chunk 10: splitting
# Chunk 11: tting.
