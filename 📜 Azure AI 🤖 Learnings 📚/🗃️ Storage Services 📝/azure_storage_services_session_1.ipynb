# %%
# !pip install azure-storage-blob PyMuPDF PyPDF2 fitz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.0/429.0 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 87.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.9/425.9 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.0/569.0 kB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 97.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import azure.storage.blob

# %%
# what are the methods are there inside the package
dir(azure.storage.blob)
# Out:
# ['AccessPolicy',
#  'AccountSasPermissions',
#  'Any',
#  'AnyStr',
#  'ArrowDialect',
#  'ArrowType',
#  'BlobAnalyticsLogging',
#  'BlobBlock',
#  'BlobClient',
#  'BlobImmutabilityPolicyMode',
#  'BlobLeaseClient',
#  'BlobPrefix',
#  'BlobProperties',
#  'BlobQueryError',
#  'BlobQueryReader',
#  'BlobSasPermissions',
#  'BlobServiceClient',
#  'BlobType',
#  'BlockState',
#  'ContainerClient',
#  'ContainerEncryptionScope',
#  'ContainerProperties',
#  'ContainerSasPermissions',
#  'ContentSettings',
#  'CopyProperties',
#  'CorsRule',
#  'CustomerProvidedEncryptionKey',
#  'DelimitedJsonDialect',
#  'DelimitedTextDialect',
#  'Dict',
#  'ExponentialRetry',
#  'FilteredBlob',
#  'IO',
#  'ImmutabilityPolicy',
#  'Iterable',
#  'LeaseProperties',
#  'LinearRetry',
#  'LocationMode',
#  'Metrics',
#  'ObjectReplicationPolicy',
#  'ObjectReplicationRule',
#  'Optional',
#  'PageRange',
#  'PartialBatchErrorException',
#  'PremiumPageBlobTier',
#  'PublicAccess',
# ...

# %%
# Method_name: BlobServiceClient

# %% [markdown]
# **Container operations**

# %% [markdown]
# $1$.$Create$ $Container$

# %%
from azure.storage.blob import BlobServiceClient

# %%
#help(BlobServiceClient)
# BlobServiceClient expecting two main arguments
# account_url: every storage service has one url
# "https://<storage_service_name>.blob.core.windows.net/"
# "https://vgp25.blob.core.windows.net/"
# https://nareshitblob.blob.core.windows.net/
# this will give information to the Blobserviceclient on which storage service it will
# you need to work on a storage account ===== > who will give the permission to enter inside the storage account

# credential

# %%
# please login to portal.azure.com
# on which storage account you need to work go to that storage: storageforde
# under the essential ==== json view will be avialable
#blob_account_url="https://storageforde.blob.core.windows.net/"
#storage_credential="MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ=="

# %% [markdown]
# https://learn.microsoft.com/en-us/azure/storage/common/storage-account-keys-manage?tabs=azure-portal

# %%
"https://nareshitmorningbatch.blob.core.windows.net/",

# %%
blob_account_url="https://nareshitblob.blob.core.windows.net/"
storage_credential="hnclryr5KBlXTFUXdJhMeXXwS347QJ0Dthf6yFvUEBJ6foY5lVnGc07HqTcSEh5QclBfIEvKID7Q+AStDA4ctg=="

# %%
blob_service_client=BlobServiceClient(account_url=blob_account_url,
                                      credential=storage_credential)

blob_service_client

# %%
#dir(blob_service_client)

# %%
#help(blob_service_client.create_container)

# %%
new_container=blob_service_client.create_container('nareshitomkarcontainer')
new_container

# %%
#all together
from azure.storage.blob import BlobServiceClient
blob_account_url="https://nareshitblob.blob.core.windows.net/"
storage_credential="hnclryr5KBlXTFUXdJhMeXXwS347QJ0Dthf6yFvUEBJ6foY5lVnGc07HqTcSEh5QclBfIEvKID7Q+AStDA4ctg=="
blob_service_client=BlobServiceClient(account_url=blob_account_url,
                                      credential=storage_credential)

new_container=blob_service_client.create_container('pythonnareshit2',public_access='Container')
new_container

# by default it will take the private

# %%
new_container.get_container_properties()
# Out:
# {'name': 'pythonnareshit2', 'last_modified': datetime.datetime(2025, 11, 18, 6, 0, 17, tzinfo=datetime.timezone.utc), 'etag': '"0x8DE2667BF8C29BA"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': {}, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x7988f9531d60>, 'immutable_storage_with_versioning_enabled': False}

# %%
type(new_container.get_container_properties())
# Out:
# azure.storage.blob._models.ContainerProperties

# %%
pandas.DataFrame({'name':'Ram','age':30},index=['0'])
# Out:
#   name  age
# 0  Ram   30

# %% [markdown]
# $Step-2$: **List out all containers**

# %%
all_containers=blob_service_client.list_containers()
all_containers

# the variable is a iterator, you need to get outputs by using for loop
for container in all_containers:
    print(container)
# Out:
# {'name': 'nareshitcontainer', 'last_modified': datetime.datetime(2025, 11, 17, 6, 24, 55, tzinfo=datetime.timezone.utc), 'etag': '"0x8DE25A2069BD688"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'blob', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x7988f808f6b0>, 'immutable_storage_with_versioning_enabled': False}
# ...

# %%
all_containers
# Out:
# <iterator object azure.core.paging.ItemPaged at 0x7b3be43169d0>

# %%
all_containers=blob_service_client.list_containers()
all_containers

# the variable is a iterator, you need to get outputs by using for loop
for container in all_containers:
    print(container['name'])
# Out:
# nareshitomkarcontainer
# pythonnareshit2
# vgpcontainer

# %%
container['name']
# Out:
# 'pythonnareshit2'

# %% [markdown]
# $Step-3$:**Delete the contaiers**

# %%
blob_service_client.delete_container('nareshitomkarcontainer')

# %%
#all together
from azure.storage.blob import BlobServiceClient
blob_account_url="https://storageforde.blob.core.windows.net/"
storage_credential="MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ=="
blob_service_client=BlobServiceClient(account_url=blob_account_url,
                                      credential=storage_credential)

new_container=blob_service_client.create_container('pythonnareshit1',public_access='Container')
new_container

# %%
all_containers=blob_service_client.list_containers()
for container in all_containers:
    print("deleting:",container['name'])
    blob_service_client.delete_container(container['name'])
# Out:
# deleting: pythonnareshit1
# deleting: pythonnareshit2
# deleting: pythonnareshit3

# %% [markdown]
# Blobserviceclint getting the access using account url and credentials
#
# - Account_url frm under essentials from the json view
#
# - Credntials : Unnder access keys we havec key

# %% [markdown]
# ### In the same way we can able to access storage accounts using connection string

# %% [markdown]
# $From$ $connection$ $string$

# %%
# from azure.storage.blob import BlobServiceClient
# connection_string='DefaultEndpointsProtocol=https;AccountName=storageforde;AccountKey=MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ==;EndpointSuffix=core.windows.net'
# blob_service_client_using_connection_string=BlobServiceClient.from_connection_string(connection_string)
# blob_service_client_using_connection_string

# %%
# from azure.storage.blob import BlobServiceClient
# blob_account_url="https://vgp25.blob.core.windows.net/"
# storage_credential="MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ=="
# blob_service_client=BlobServiceClient(account_url=blob_account_url,
#                                       credential=storage_credential)

# #=============================================================================
# from azure.storage.blob import BlobServiceClient
# connection_string='DefaultEndpointsProtocol=https;AccountName=storageforde;AccountKey=MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ==;EndpointSuffix=core.windows.net'
# blob_service_client_using_connection_string=BlobServiceClient.from_connection_string(connection_string)
# blob_service_client_using_connection_string

# %%
blob_service_client_using_connection_string.get_account_information()
# Out:
# {'client_request_id': 'f37e4492-0f8a-11ee-97d8-0242ac1c000c',
#  'request_id': 'd40cc8d2-f01e-0037-3497-a37e91000000',
#  'version': '2022-11-02',
#  'date': datetime.datetime(2023, 6, 20, 16, 53, 15, tzinfo=datetime.timezone.utc),
#  'sku_name': 'Standard_LRS',
#  'account_kind': 'StorageV2',
#  'is_hns_enabled': False}

# %%
# blobs =====> data files inside the container
# storage_account_name= storageforde
# container_name=pythonnareshit1
# blob= bank.csv

# %% [markdown]
# **get_container_client**: to interact with container

# %%
from azure.storage.blob import BlobServiceClient
connection_string='DefaultEndpointsProtocol=https;AccountName=nareshitblob;AccountKey=hnclryr5KBlXTFUXdJhMeXXwS347QJ0Dthf6yFvUEBJ6foY5lVnGc07HqTcSEh5QclBfIEvKID7Q+AStDA4ctg==;EndpointSuffix=core.windows.net'
blob_service_client_using_connection_string=BlobServiceClient.from_connection_string(connection_string)
blob_service_client_using_connection_string

# %%
container_client=blob_service_client_using_connection_string \
                 .get_container_client("nareshitcontainer")
container_client

# %%
for blob in container_client.list_blobs():
    print(blob)
# Out:
# {'name': 'Attention_all_you_need.pdf', 'container': 'nareshitcontainer', 'snapshot': None, 'version_id': None, 'is_current_version': None, 'blob_type': <BlobType.BLOCKBLOB: 'BlockBlob'>, 'metadata': {}, 'encrypted_metadata': None, 'last_modified': datetime.datetime(2025, 11, 17, 6, 17, 21, tzinfo=datetime.timezone.utc), 'etag': '0x8DE25A0F80F54B4', 'size': 2215244, 'content_range': None, 'append_blob_committed_block_count': None, 'is_append_blob_sealed': None, 'page_blob_sequence_number': None, 'server_encrypted': True, 'copy': {'id': None, 'source': None, 'status': None, 'progress': None, 'completion_time': None, 'status_description': None, 'incremental_copy': None, 'destination_snapshot': None}, 'content_settings': {'content_type': 'application/pdf', 'content_encoding': None, 'content_language': None, 'content_md5': bytearray(b'\x18\xe1\xb0\x07\xa1\xda\xb4[0\xcc\x86\x1b\xa2\xdf\xda%'), 'content_disposition': None, 'cache_control': None}, 'lease': {'status': 'unlocked', 'state': 'av
# ...

# %%
container_client=blob_service_client_using_connection_string \
                 .get_container_client("nareshitcontainer")
for blob in container_client.list_blobs():
    print(blob['name'])
# Out:
# Attention_all_you_need.pdf

# %% [markdown]
# **get_blob_client**: to interact with blob

# %% [markdown]
# ## Pdf data

# %%
blob_client=blob_service_client_using_connection_string \
            .get_blob_client("nareshitcontainer","Attention_all_you_need.pdf")

pdf_data=blob_client.download_blob()
pdf_bytes=pdf_data.readall()
len(pdf_bytes)
# Out:
# 2215244

# %%
#!pip install PyPDF2

# %%
from PyPDF2 import PdfReader
import io
pdf_reader=PdfReader(io.BytesIO(pdf_bytes))
print(pdf_reader.pages[2].extract_text())
# Out:
# Figure 1: The Transformer - model architecture.
# The Transformer follows this overall architecture using stacked self-attention and point-wise, fully
# connected layers for both the encoder and decoder, shown in the left and right halves of Figure 1,
# respectively.
# 3.1 Encoder and Decoder Stacks
# Encoder: The encoder is composed of a stack of N= 6 identical layers. Each layer has two
# sub-layers. The first is a multi-head self-attention mechanism, and the second is a simple, position-
# wise fully connected feed-forward network. We employ a residual connection [ 11] around each of
# the two sub-layers, followed by layer normalization [ 1]. That is, the output of each sub-layer is
# LayerNorm( x+ Sublayer( x)), where Sublayer( x)is the function implemented by the sub-layer
# itself. To facilitate these residual connections, all sub-layers in the model, as well as the embedding
# layers, produce outputs of dimension dmodel = 512 .
# ...

# %% [markdown]
# - PyPDF2 is not extracting images
#
# - for that we need to use Pymupdf and fitz

# %%
# !pip install fitz

# %%
import fitz  # PyMuPDF
import io

doc = fitz.open(stream=pdf_bytes, filetype="pdf")

for page_index in range(len(doc)):
    page = doc[page_index]
    image_list = page.get_images(full=True)

    for img_index, img in enumerate(image_list):
        xref = img[0]
        pix = fitz.Pixmap(doc, xref)

        if pix.alpha:  # handle alpha channel
            pix = fitz.Pixmap(fitz.csRGB, pix)

        pix.save(f"page{page_index}_img{img_index}.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3298098190.py in <cell line: 0>()
#       2 import io
#       3
# ----> 4 doc = fitz.open(stream=pdf_bytes, filetype="pdf")
#       5
#       6 for page_index in range(len(doc)):
#
# AttributeError: module 'fitz' has no attribute 'open'

# %%
# !pip uninstall -y fitz
# Out:
# Found existing installation: fitz 0.0.1.dev2
# Uninstalling fitz-0.0.1.dev2:
#   Successfully uninstalled fitz-0.0.1.dev2

# %%
# !pip install --upgrade PyMuPDF

# %%
import sys
if 'fitz' in sys.modules:
    del sys.modules['fitz']

import fitz  # PyMuPDF
import io

doc = fitz.open(stream=pdf_bytes, filetype="pdf")

for page_index in range(len(doc)):
    page = doc[page_index]
    image_list = page.get_images(full=True)

    for img_index, img in enumerate(image_list):
        xref = img[0]
        pix = fitz.Pixmap(doc, xref)

        if pix.alpha:  # handle alpha channel
            pix = fitz.Pixmap(fitz.csRGB, pix)

        pix.save(f"page{page_index}_img{img_index}.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3540711906.py in <cell line: 0>()
#       2 import io
#       3
# ----> 4 doc = fitz.open(stream=pdf_bytes, filetype="pdf")
#       5
#       6 for page_index in range(len(doc)):
#
# AttributeError: module 'fitz' has no attribute 'open'

# %%
blob_client=blob_service_client_using_connection_string \
            .get_blob_client("vgpcontainer","Visadataset.csv")

data=blob_client.download_blob()
# we will write the data of bank.csv in another files

import pandas as pd
pd.read_csv(data)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
pd.read_csv(data)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
from azure.storage.blob import BlobServiceClient
blob_account_url="https://storageforde.blob.core.windows.net/"
storage_credential="MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ=="
blob_service_client=BlobServiceClient(account_url=blob_account_url,
                                      credential=storage_credential)

blob_client=blob_service_client \
            .get_blob_client("pythonnareshit1","bank.csv")

data=blob_client.download_blob()
# we will write the data of bank.csv in another files

import pandas as pd
pd.read_csv(data,sep=';')

#=============================================================================
from azure.storage.blob import BlobServiceClient
connection_string='DefaultEndpointsProtocol=https;AccountName=storageforde;AccountKey=MfHfi/aTTNq/jNoyz31qA89Hy7c4N24TspPqeML99eyPS9mhOsQ6cOH0hUhbmReeg3TFGfx7CdjH+AStMYaESQ==;EndpointSuffix=core.windows.net'
blob_service_client_using_connection_string=BlobServiceClient.from_connection_string(connection_string)


blob_client=blob_service_client_using_connection_string \
            .get_blob_client("pythonnareshit1","bank.csv")

data=blob_client.download_blob()
# we will write the data of bank.csv in another files

import pandas as pd
pd.read_csv(data,sep=';')
