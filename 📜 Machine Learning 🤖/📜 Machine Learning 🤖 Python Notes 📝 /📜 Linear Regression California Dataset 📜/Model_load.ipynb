# %%
import pickle

# %%
location=open('california_model.pkl','rb')
loaded_model1=pickle.load(location)
loaded_model1
# Out:
# {'model': LinearRegression(),
#  'cols': Index(['MedInc', 'HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Latitude'], dtype='object')}

# %%
loaded_model1['model'].predict([[10,20,30,40,50,60]])
# Out:
# E:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.91480993])

# %%
import joblib
import warnings
warnings.filterwarnings('ignore')
location= 'california_model.joblib'
saved_model=joblib.load(location)
saved_model['model'].predict([[10,20,30,40,50,60]])
# Out:
# array([5.91480993])
